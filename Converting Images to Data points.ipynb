# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2             #image operations
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
import path

# %%
print(os.getcwd())
dir0 = os.getcwd()
os.chdir(dir0)
# files = os.listdir()
print(dir0)
dir1 = dir0 + "\\images\\"
dir_rock = dir1 + "\\rock"
dir_paper = dir1 + "\\paper\\"
dir_scissors = dir1 + "\\scissors\\"
dir_empty = dir1 + "\\empty\\"
# os.chdir(dir2)
# Out:
# C:\Users\ggp\Deep Learning Codes\rock paper scissors
# C:\Users\ggp\Deep Learning Codes\rock paper scissors

# %%
Categories = ["scissors","rock", "paper", "lizard", "spock", "empty"]
for category in Categories:
    path = os.path.join(dir1, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img))
        plt.imshow(img_array, cmap = "gray")
#         
        plt.show()
        break
    break

# %%
print(img_array.shape)
# Out:
# (200, 200, 3)

# %%
img_size = 200
# new_array = cv2.resize(img_array, (img_size,img_size))
# plt.imshow(new_array, cmap = 'gray')
# print(new_array.shape)
# plt.show()

# %%
# print(new_array.shape)

# %%
training_data = []

# %%
def create_training_data():
    for category in Categories:
        path = os.path.join(dir1, category)
        class_num = Categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img))
                training_data.append([img_array, class_num])
                print("Works in Image" + str(img))
            except:
                print("Error in Image:" + str(img))

# %%
create_training_data()
# Out:
# Works in Imageopencv_frame_0.png
# Works in Imageopencv_frame_1.png
# Works in Imageopencv_frame_10.png
# Works in Imageopencv_frame_100.png
# Works in Imageopencv_frame_101.png
# Works in Imageopencv_frame_102.png
# Works in Imageopencv_frame_103.png
# Works in Imageopencv_frame_104.png
# Works in Imageopencv_frame_105.png
# Works in Imageopencv_frame_106.png
# Works in Imageopencv_frame_107.png
# Works in Imageopencv_frame_108.png
# Works in Imageopencv_frame_109.png
# Works in Imageopencv_frame_11.png
# Works in Imageopencv_frame_110.png
# Works in Imageopencv_frame_111.png
# Works in Imageopencv_frame_112.png
# Works in Imageopencv_frame_113.png
# Works in Imageopencv_frame_114.png
# Works in Imageopencv_frame_115.png
# Works in Imageopencv_frame_116.png
# Works in Imageopencv_frame_117.png
# Works in Imageopencv_frame_118.png
# Works in Imageopencv_frame_119.png
# Works in Imageopencv_frame_12.png
# Works in Imageopencv_frame_120.png
# Works in Imageopencv_frame_121.png
# ...

# %%
print(len(training_data))
# Out:
# 3029

# %%
import random
random.shuffle(training_data)

# %%
# for sample in training_data[30:100]:
#     print(sample[1])

# %%
X = []
Y = []

# %%
for features, labels in training_data:
    X.append(features)
    Y.append(labels)
X = np.array(X).reshape(-1, img_size, img_size, 3)

# %%
import pickle
pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("Y.pickle", "wb")
pickle.dump(Y, pickle_out)
pickle_out.close()

# %%
pickle_in = open("X.pickle", "rb")
X = pickle.load(pickle_in)
print(X[0].shape)
# Out:
# (200, 200, 3)

# %%
plt.imshow(X[120])
print(Y[120])
# Out:
# 4
