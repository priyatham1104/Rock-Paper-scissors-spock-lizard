# %%
######### Squeeze net ############
# 1) Collecting an image dataset
# 2) Squeeze Net (only retraining the final layers)
# 3) Training
# 4) Testing
# 5) Make somthing intersting out of it

# %%
############# Gather Images #############

# %%
import cv2
import os
from os import path
import sys

# %%
dir0 = os.getcwd()
print(dir0)
dir_img = dir0 + "\\images"
print(dir_img)
# Out:
# C:\Users\ggp\Deep Learning Codes\rock paper scissors
# C:\Users\ggp\Deep Learning Codes\rock paper scissors\images

# %%
def get_images(name):
    os.chdir(dir_img)
    try:
        os.mkdir(name)
    except:
        print("Couldn't make a directory")
    img_counter = 0
    dir_new = dir_img + name
    os.chdir(name)
    cam = cv2.VideoCapture(0)
#     cv2.namedWindow("test")
    while True:
        ret, frame = cam.read()
        if not ret:
            print("failed to grab frame")
            break
#         cv2.imshow("test", frame)
        cv2.rectangle(frame, (0, 0), (250, 250), (255, 255, 255), 2)
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(frame, "Collecting {}".format(img_counter),
            (300, 20), font, 0.7, (0, 255, 255), 2, cv2.LINE_AA)
        cv2.imshow("Collecting images", frame)
        k = cv2.waitKey(1)
        if k%256 == 27:
            # ESC pressed
            print("Escape hit, closing...")
            break
        elif k%256 == 32:
            # SPACE pressed
            roi = frame[50:250, 50:250]
            img_name = "opencv_frame_{}.png".format(img_counter)
            cv2.imwrite(img_name, roi)
            print("{} written!".format(img_name))
            img_counter += 1

    cam.release()

    cv2.destroyAllWindows()
    os.chdir(dir0)

# %%
get_images("scissors")
# Out:
# Couldn't make a directory
# opencv_frame_0.png written!
# opencv_frame_1.png written!
# opencv_frame_2.png written!
# opencv_frame_3.png written!
# opencv_frame_4.png written!
# opencv_frame_5.png written!
# opencv_frame_6.png written!
# opencv_frame_7.png written!
# opencv_frame_8.png written!
# opencv_frame_9.png written!
# opencv_frame_10.png written!
# opencv_frame_11.png written!
# opencv_frame_12.png written!
# opencv_frame_13.png written!
# opencv_frame_14.png written!
# opencv_frame_15.png written!
# opencv_frame_16.png written!
# opencv_frame_17.png written!
# opencv_frame_18.png written!
# opencv_frame_19.png written!
# opencv_frame_20.png written!
# opencv_frame_21.png written!
# opencv_frame_22.png written!
# opencv_frame_23.png written!
# opencv_frame_24.png written!
# opencv_frame_25.png written!
# opencv_frame_26.png written!
# opencv_frame_27.png written!
# opencv_frame_28.png written!
# opencv_frame_29.png written!
# opencv_frame_30.png written!
# opencv_frame_31.png written!
# opencv_frame_32.png written!
# opencv_frame_33.png written!
# opencv_frame_34.png written!
# opencv_frame_35.png written!
# opencv_frame_36.png written!
# opencv_frame_37.png written!
# opencv_frame_38.png written!
# opencv_frame_39.png written!
# opencv_frame_40.png written!
# opencv_frame_41.png written!
# opencv_frame_42.png written!
# opencv_frame_43.png written!
# opencv_frame_44.png written!
# opencv_frame_45.png written!
# opencv_frame_46.png written!
# opencv_frame_47.png written!
# opencv_frame_48.png written!
# opencv_frame_49.png written!
# opencv_frame_50.png written!
# opencv_frame_51.png written!
# opencv_frame_52.png written!
# opencv_frame_53.png written!
# opencv_frame_54.png written!
# opencv_frame_55.png written!
# opencv_frame_56.png written!
# opencv_frame_57.png written!
# opencv_frame_58.png written!
# opencv_frame_59.png written!
# opencv_frame_60.png written!
# opencv_frame_61.png written!
# opencv_frame_62.png written!
# opencv_frame_63.png written!
# opencv_frame_64.png written!
# opencv_frame_65.png written!
# opencv_frame_66.png written!
# opencv_frame_67.png written!
# opencv_frame_68.png written!
# opencv_frame_69.png written!
# opencv_frame_70.png written!
# opencv_frame_71.png written!
# opencv_frame_72.png written!
# opencv_frame_73.png written!
# opencv_frame_74.png written!
# opencv_frame_75.png written!
# opencv_frame_76.png written!
# opencv_frame_77.png written!
# opencv_frame_78.png written!
# opencv_frame_79.png written!
# opencv_frame_80.png written!
# opencv_frame_81.png written!
# opencv_frame_82.png written!
# opencv_frame_83.png written!
# opencv_frame_84.png written!
# opencv_frame_85.png written!
# opencv_frame_86.png written!
# opencv_frame_87.png written!
# opencv_frame_88.png written!
# opencv_frame_89.png written!
# opencv_frame_90.png written!
# opencv_frame_91.png written!
# opencv_frame_92.png written!
# opencv_frame_93.png written!
# opencv_frame_94.png written!
# opencv_frame_95.png written!
# opencv_frame_96.png written!
# opencv_frame_97.png written!
# opencv_frame_98.png written!
# opencv_frame_99.png written!
# opencv_frame_100.png written!
# opencv_frame_101.png written!
# opencv_frame_102.png written!
# opencv_frame_103.png written!
# opencv_frame_104.png written!
# opencv_frame_105.png written!
# opencv_frame_106.png written!
# opencv_frame_107.png written!
# opencv_frame_108.png written!
# opencv_frame_109.png written!
# opencv_frame_110.png written!
# opencv_frame_111.png written!
# opencv_frame_112.png written!
# opencv_frame_113.png written!
# opencv_frame_114.png written!
# opencv_frame_115.png written!
# opencv_frame_116.png written!
# opencv_frame_117.png written!
# opencv_frame_118.png written!
# opencv_frame_119.png written!
# opencv_frame_120.png written!
# opencv_frame_121.png written!
# opencv_frame_122.png written!
# opencv_frame_123.png written!
# opencv_frame_124.png written!
# opencv_frame_125.png written!
# opencv_frame_126.png written!
# opencv_frame_127.png written!
# opencv_frame_128.png written!
# opencv_frame_129.png written!
# opencv_frame_130.png written!
# opencv_frame_131.png written!
# opencv_frame_132.png written!
# opencv_frame_133.png written!
# opencv_frame_134.png written!
# opencv_frame_135.png written!
# opencv_frame_136.png written!
# opencv_frame_137.png written!
# opencv_frame_138.png written!
# opencv_frame_139.png written!
# opencv_frame_140.png written!
# opencv_frame_141.png written!
# opencv_frame_142.png written!
# opencv_frame_143.png written!
# opencv_frame_144.png written!
# opencv_frame_145.png written!
# opencv_frame_146.png written!
# opencv_frame_147.png written!
# opencv_frame_148.png written!
# opencv_frame_149.png written!
# opencv_frame_150.png written!
# opencv_frame_151.png written!
# opencv_frame_152.png written!
# opencv_frame_153.png written!
# opencv_frame_154.png written!
# opencv_frame_155.png written!
# opencv_frame_156.png written!
# opencv_frame_157.png written!
# opencv_frame_158.png written!
# opencv_frame_159.png written!
# opencv_frame_160.png written!
# opencv_frame_161.png written!
# opencv_frame_162.png written!
# opencv_frame_163.png written!
# opencv_frame_164.png written!
# opencv_frame_165.png written!
# opencv_frame_166.png written!
# opencv_frame_167.png written!
# opencv_frame_168.png written!
# opencv_frame_169.png written!
# opencv_frame_170.png written!
# opencv_frame_171.png written!
# opencv_frame_172.png written!
# opencv_frame_173.png written!
# opencv_frame_174.png written!
# opencv_frame_175.png written!
# opencv_frame_176.png written!
# opencv_frame_177.png written!
# opencv_frame_178.png written!
# opencv_frame_179.png written!
# opencv_frame_180.png written!
# opencv_frame_181.png written!
# opencv_frame_182.png written!
# opencv_frame_183.png written!
# opencv_frame_184.png written!
# opencv_frame_185.png written!
# opencv_frame_186.png written!
# opencv_frame_187.png written!
# opencv_frame_188.png written!
# opencv_frame_189.png written!
# opencv_frame_190.png written!
# opencv_frame_191.png written!
# opencv_frame_192.png written!
# opencv_frame_193.png written!
# opencv_frame_194.png written!
# opencv_frame_195.png written!
# opencv_frame_196.png written!
# opencv_frame_197.png written!
# opencv_frame_198.png written!
# opencv_frame_199.png written!
# opencv_frame_200.png written!
# opencv_frame_201.png written!
# opencv_frame_202.png written!
# opencv_frame_203.png written!
# opencv_frame_204.png written!
# opencv_frame_205.png written!
# opencv_frame_206.png written!
# opencv_frame_207.png written!
# opencv_frame_208.png written!
# opencv_frame_209.png written!
# opencv_frame_210.png written!
# opencv_frame_211.png written!
# opencv_frame_212.png written!
# opencv_frame_213.png written!
# opencv_frame_214.png written!
# opencv_frame_215.png written!
# opencv_frame_216.png written!
# opencv_frame_217.png written!
# opencv_frame_218.png written!
# opencv_frame_219.png written!
# opencv_frame_220.png written!
# opencv_frame_221.png written!
# opencv_frame_222.png written!
# opencv_frame_223.png written!
# opencv_frame_224.png written!
# opencv_frame_225.png written!
# opencv_frame_226.png written!
# opencv_frame_227.png written!
# opencv_frame_228.png written!
# opencv_frame_229.png written!
# opencv_frame_230.png written!
# opencv_frame_231.png written!
# opencv_frame_232.png written!
# opencv_frame_233.png written!
# opencv_frame_234.png written!
# opencv_frame_235.png written!
# opencv_frame_236.png written!
# opencv_frame_237.png written!
# opencv_frame_238.png written!
# opencv_frame_239.png written!
# opencv_frame_240.png written!
# opencv_frame_241.png written!
# opencv_frame_242.png written!
# opencv_frame_243.png written!
# opencv_frame_244.png written!
# opencv_frame_245.png written!
# opencv_frame_246.png written!
# opencv_frame_247.png written!
# opencv_frame_248.png written!
# opencv_frame_249.png written!
# opencv_frame_250.png written!
# opencv_frame_251.png written!
# opencv_frame_252.png written!
# opencv_frame_253.png written!
# opencv_frame_254.png written!
# opencv_frame_255.png written!
# opencv_frame_256.png written!
# opencv_frame_257.png written!
# opencv_frame_258.png written!
# opencv_frame_259.png written!
# opencv_frame_260.png written!
# opencv_frame_261.png written!
# opencv_frame_262.png written!
# opencv_frame_263.png written!
# opencv_frame_264.png written!
# opencv_frame_265.png written!
# opencv_frame_266.png written!
# opencv_frame_267.png written!
# opencv_frame_268.png written!
# opencv_frame_269.png written!
# opencv_frame_270.png written!
# opencv_frame_271.png written!
# opencv_frame_272.png written!
# opencv_frame_273.png written!
# opencv_frame_274.png written!
# opencv_frame_275.png written!
# opencv_frame_276.png written!
# opencv_frame_277.png written!
# opencv_frame_278.png written!
# opencv_frame_279.png written!
# opencv_frame_280.png written!
# opencv_frame_281.png written!
# opencv_frame_282.png written!
# opencv_frame_283.png written!
# opencv_frame_284.png written!
# opencv_frame_285.png written!
# opencv_frame_286.png written!
# opencv_frame_287.png written!
# opencv_frame_288.png written!
# opencv_frame_289.png written!
# opencv_frame_290.png written!
# opencv_frame_291.png written!
# opencv_frame_292.png written!
# opencv_frame_293.png written!
# opencv_frame_294.png written!
# opencv_frame_295.png written!
# opencv_frame_296.png written!
# opencv_frame_297.png written!
# opencv_frame_298.png written!
# opencv_frame_299.png written!
# opencv_frame_300.png written!
# opencv_frame_301.png written!
# opencv_frame_302.png written!
# opencv_frame_303.png written!
# opencv_frame_304.png written!
# opencv_frame_305.png written!
# opencv_frame_306.png written!
# opencv_frame_307.png written!
# opencv_frame_308.png written!
# opencv_frame_309.png written!
# opencv_frame_310.png written!
# opencv_frame_311.png written!
# opencv_frame_312.png written!
# opencv_frame_313.png written!
# opencv_frame_314.png written!
# opencv_frame_315.png written!
# opencv_frame_316.png written!
# opencv_frame_317.png written!
# opencv_frame_318.png written!
# opencv_frame_319.png written!
# opencv_frame_320.png written!
# opencv_frame_321.png written!
# opencv_frame_322.png written!
# opencv_frame_323.png written!
# opencv_frame_324.png written!
# opencv_frame_325.png written!
# opencv_frame_326.png written!
# opencv_frame_327.png written!
# opencv_frame_328.png written!
# opencv_frame_329.png written!
# opencv_frame_330.png written!
# opencv_frame_331.png written!
# opencv_frame_332.png written!
# opencv_frame_333.png written!
# opencv_frame_334.png written!
# opencv_frame_335.png written!
# opencv_frame_336.png written!
# opencv_frame_337.png written!
# opencv_frame_338.png written!
# opencv_frame_339.png written!
# opencv_frame_340.png written!
# opencv_frame_341.png written!
# opencv_frame_342.png written!
# opencv_frame_343.png written!
# opencv_frame_344.png written!
# opencv_frame_345.png written!
# opencv_frame_346.png written!
# opencv_frame_347.png written!
# opencv_frame_348.png written!
# opencv_frame_349.png written!
# opencv_frame_350.png written!
# opencv_frame_351.png written!
# opencv_frame_352.png written!
# opencv_frame_353.png written!
# opencv_frame_354.png written!
# opencv_frame_355.png written!
# opencv_frame_356.png written!
# opencv_frame_357.png written!
# opencv_frame_358.png written!
# opencv_frame_359.png written!
# opencv_frame_360.png written!
# opencv_frame_361.png written!
# opencv_frame_362.png written!
# opencv_frame_363.png written!
# opencv_frame_364.png written!
# opencv_frame_365.png written!
# opencv_frame_366.png written!
# opencv_frame_367.png written!
# opencv_frame_368.png written!
# opencv_frame_369.png written!
# opencv_frame_370.png written!
# opencv_frame_371.png written!
# opencv_frame_372.png written!
# opencv_frame_373.png written!
# opencv_frame_374.png written!
# opencv_frame_375.png written!
# opencv_frame_376.png written!
# opencv_frame_377.png written!
# opencv_frame_378.png written!
# opencv_frame_379.png written!
# opencv_frame_380.png written!
# opencv_frame_381.png written!
# opencv_frame_382.png written!
# opencv_frame_383.png written!
# opencv_frame_384.png written!
# opencv_frame_385.png written!
# opencv_frame_386.png written!
# opencv_frame_387.png written!
# opencv_frame_388.png written!
# opencv_frame_389.png written!
# opencv_frame_390.png written!
# opencv_frame_391.png written!
# opencv_frame_392.png written!
# opencv_frame_393.png written!
# opencv_frame_394.png written!
# opencv_frame_395.png written!
# opencv_frame_396.png written!
# opencv_frame_397.png written!
# opencv_frame_398.png written!
# opencv_frame_399.png written!
# opencv_frame_400.png written!
# opencv_frame_401.png written!
# opencv_frame_402.png written!
# opencv_frame_403.png written!
# opencv_frame_404.png written!
# opencv_frame_405.png written!
# opencv_frame_406.png written!
# opencv_frame_407.png written!
# opencv_frame_408.png written!
# opencv_frame_409.png written!
# opencv_frame_410.png written!
# opencv_frame_411.png written!
# opencv_frame_412.png written!
# opencv_frame_413.png written!
# opencv_frame_414.png written!
# opencv_frame_415.png written!
# opencv_frame_416.png written!
# opencv_frame_417.png written!
# opencv_frame_418.png written!
# opencv_frame_419.png written!
# opencv_frame_420.png written!
# opencv_frame_421.png written!
# opencv_frame_422.png written!
# opencv_frame_423.png written!
# opencv_frame_424.png written!
# opencv_frame_425.png written!
# opencv_frame_426.png written!
# opencv_frame_427.png written!
# opencv_frame_428.png written!
# opencv_frame_429.png written!
# opencv_frame_430.png written!
# opencv_frame_431.png written!
# opencv_frame_432.png written!
# opencv_frame_433.png written!
# opencv_frame_434.png written!
# opencv_frame_435.png written!
# opencv_frame_436.png written!
# opencv_frame_437.png written!
# opencv_frame_438.png written!
# opencv_frame_439.png written!
# opencv_frame_440.png written!
# opencv_frame_441.png written!
# opencv_frame_442.png written!
# opencv_frame_443.png written!
# opencv_frame_444.png written!
# opencv_frame_445.png written!
# opencv_frame_446.png written!
# opencv_frame_447.png written!
# opencv_frame_448.png written!
# opencv_frame_449.png written!
# opencv_frame_450.png written!
# opencv_frame_451.png written!
# opencv_frame_452.png written!
# opencv_frame_453.png written!
# opencv_frame_454.png written!
# opencv_frame_455.png written!
# opencv_frame_456.png written!
# opencv_frame_457.png written!
# opencv_frame_458.png written!
# opencv_frame_459.png written!
# opencv_frame_460.png written!
# opencv_frame_461.png written!
# opencv_frame_462.png written!
# opencv_frame_463.png written!
# opencv_frame_464.png written!
# opencv_frame_465.png written!
# opencv_frame_466.png written!
# opencv_frame_467.png written!
# opencv_frame_468.png written!
# opencv_frame_469.png written!
# opencv_frame_470.png written!
# opencv_frame_471.png written!
# opencv_frame_472.png written!
# opencv_frame_473.png written!
# opencv_frame_474.png written!
# opencv_frame_475.png written!
# opencv_frame_476.png written!
# opencv_frame_477.png written!
# opencv_frame_478.png written!
# opencv_frame_479.png written!
# opencv_frame_480.png written!
# opencv_frame_481.png written!
# opencv_frame_482.png written!
# opencv_frame_483.png written!
# opencv_frame_484.png written!
# opencv_frame_485.png written!
# opencv_frame_486.png written!
# opencv_frame_487.png written!
# opencv_frame_488.png written!
# opencv_frame_489.png written!
# opencv_frame_490.png written!
# opencv_frame_491.png written!
# opencv_frame_492.png written!
# opencv_frame_493.png written!
# opencv_frame_494.png written!
# opencv_frame_495.png written!
# opencv_frame_496.png written!
# opencv_frame_497.png written!
# opencv_frame_498.png written!
# opencv_frame_499.png written!
# Escape hit, closing...

# %%
get_images("paper")
# Out:
# Couldn't make a directory
# opencv_frame_0.png written!
# opencv_frame_1.png written!
# opencv_frame_2.png written!
# opencv_frame_3.png written!
# opencv_frame_4.png written!
# opencv_frame_5.png written!
# opencv_frame_6.png written!
# opencv_frame_7.png written!
# opencv_frame_8.png written!
# opencv_frame_9.png written!
# opencv_frame_10.png written!
# opencv_frame_11.png written!
# opencv_frame_12.png written!
# opencv_frame_13.png written!
# opencv_frame_14.png written!
# opencv_frame_15.png written!
# opencv_frame_16.png written!
# opencv_frame_17.png written!
# opencv_frame_18.png written!
# opencv_frame_19.png written!
# opencv_frame_20.png written!
# opencv_frame_21.png written!
# opencv_frame_22.png written!
# opencv_frame_23.png written!
# opencv_frame_24.png written!
# opencv_frame_25.png written!
# opencv_frame_26.png written!
# opencv_frame_27.png written!
# opencv_frame_28.png written!
# opencv_frame_29.png written!
# opencv_frame_30.png written!
# opencv_frame_31.png written!
# opencv_frame_32.png written!
# opencv_frame_33.png written!
# opencv_frame_34.png written!
# opencv_frame_35.png written!
# opencv_frame_36.png written!
# opencv_frame_37.png written!
# opencv_frame_38.png written!
# opencv_frame_39.png written!
# opencv_frame_40.png written!
# opencv_frame_41.png written!
# opencv_frame_42.png written!
# opencv_frame_43.png written!
# opencv_frame_44.png written!
# opencv_frame_45.png written!
# opencv_frame_46.png written!
# opencv_frame_47.png written!
# opencv_frame_48.png written!
# opencv_frame_49.png written!
# opencv_frame_50.png written!
# opencv_frame_51.png written!
# opencv_frame_52.png written!
# opencv_frame_53.png written!
# opencv_frame_54.png written!
# opencv_frame_55.png written!
# opencv_frame_56.png written!
# opencv_frame_57.png written!
# opencv_frame_58.png written!
# opencv_frame_59.png written!
# opencv_frame_60.png written!
# opencv_frame_61.png written!
# opencv_frame_62.png written!
# opencv_frame_63.png written!
# opencv_frame_64.png written!
# opencv_frame_65.png written!
# opencv_frame_66.png written!
# opencv_frame_67.png written!
# opencv_frame_68.png written!
# opencv_frame_69.png written!
# opencv_frame_70.png written!
# opencv_frame_71.png written!
# opencv_frame_72.png written!
# opencv_frame_73.png written!
# opencv_frame_74.png written!
# opencv_frame_75.png written!
# opencv_frame_76.png written!
# opencv_frame_77.png written!
# opencv_frame_78.png written!
# opencv_frame_79.png written!
# opencv_frame_80.png written!
# opencv_frame_81.png written!
# opencv_frame_82.png written!
# opencv_frame_83.png written!
# opencv_frame_84.png written!
# opencv_frame_85.png written!
# opencv_frame_86.png written!
# opencv_frame_87.png written!
# opencv_frame_88.png written!
# opencv_frame_89.png written!
# opencv_frame_90.png written!
# opencv_frame_91.png written!
# opencv_frame_92.png written!
# opencv_frame_93.png written!
# opencv_frame_94.png written!
# opencv_frame_95.png written!
# opencv_frame_96.png written!
# opencv_frame_97.png written!
# opencv_frame_98.png written!
# opencv_frame_99.png written!
# opencv_frame_100.png written!
# opencv_frame_101.png written!
# opencv_frame_102.png written!
# opencv_frame_103.png written!
# opencv_frame_104.png written!
# opencv_frame_105.png written!
# opencv_frame_106.png written!
# opencv_frame_107.png written!
# opencv_frame_108.png written!
# opencv_frame_109.png written!
# opencv_frame_110.png written!
# opencv_frame_111.png written!
# opencv_frame_112.png written!
# opencv_frame_113.png written!
# opencv_frame_114.png written!
# opencv_frame_115.png written!
# opencv_frame_116.png written!
# opencv_frame_117.png written!
# opencv_frame_118.png written!
# opencv_frame_119.png written!
# opencv_frame_120.png written!
# opencv_frame_121.png written!
# opencv_frame_122.png written!
# opencv_frame_123.png written!
# opencv_frame_124.png written!
# opencv_frame_125.png written!
# opencv_frame_126.png written!
# opencv_frame_127.png written!
# opencv_frame_128.png written!
# opencv_frame_129.png written!
# opencv_frame_130.png written!
# opencv_frame_131.png written!
# opencv_frame_132.png written!
# opencv_frame_133.png written!
# opencv_frame_134.png written!
# opencv_frame_135.png written!
# opencv_frame_136.png written!
# opencv_frame_137.png written!
# opencv_frame_138.png written!
# opencv_frame_139.png written!
# opencv_frame_140.png written!
# opencv_frame_141.png written!
# opencv_frame_142.png written!
# opencv_frame_143.png written!
# opencv_frame_144.png written!
# opencv_frame_145.png written!
# opencv_frame_146.png written!
# opencv_frame_147.png written!
# opencv_frame_148.png written!
# opencv_frame_149.png written!
# opencv_frame_150.png written!
# opencv_frame_151.png written!
# opencv_frame_152.png written!
# opencv_frame_153.png written!
# opencv_frame_154.png written!
# opencv_frame_155.png written!
# opencv_frame_156.png written!
# opencv_frame_157.png written!
# opencv_frame_158.png written!
# opencv_frame_159.png written!
# opencv_frame_160.png written!
# opencv_frame_161.png written!
# opencv_frame_162.png written!
# opencv_frame_163.png written!
# opencv_frame_164.png written!
# opencv_frame_165.png written!
# opencv_frame_166.png written!
# opencv_frame_167.png written!
# opencv_frame_168.png written!
# opencv_frame_169.png written!
# opencv_frame_170.png written!
# opencv_frame_171.png written!
# opencv_frame_172.png written!
# opencv_frame_173.png written!
# opencv_frame_174.png written!
# opencv_frame_175.png written!
# opencv_frame_176.png written!
# opencv_frame_177.png written!
# opencv_frame_178.png written!
# opencv_frame_179.png written!
# opencv_frame_180.png written!
# opencv_frame_181.png written!
# opencv_frame_182.png written!
# opencv_frame_183.png written!
# opencv_frame_184.png written!
# opencv_frame_185.png written!
# opencv_frame_186.png written!
# opencv_frame_187.png written!
# opencv_frame_188.png written!
# opencv_frame_189.png written!
# opencv_frame_190.png written!
# opencv_frame_191.png written!
# opencv_frame_192.png written!
# opencv_frame_193.png written!
# opencv_frame_194.png written!
# opencv_frame_195.png written!
# opencv_frame_196.png written!
# opencv_frame_197.png written!
# opencv_frame_198.png written!
# opencv_frame_199.png written!
# opencv_frame_200.png written!
# opencv_frame_201.png written!
# opencv_frame_202.png written!
# opencv_frame_203.png written!
# opencv_frame_204.png written!
# opencv_frame_205.png written!
# opencv_frame_206.png written!
# opencv_frame_207.png written!
# opencv_frame_208.png written!
# opencv_frame_209.png written!
# opencv_frame_210.png written!
# opencv_frame_211.png written!
# opencv_frame_212.png written!
# opencv_frame_213.png written!
# opencv_frame_214.png written!
# opencv_frame_215.png written!
# opencv_frame_216.png written!
# opencv_frame_217.png written!
# opencv_frame_218.png written!
# opencv_frame_219.png written!
# opencv_frame_220.png written!
# opencv_frame_221.png written!
# opencv_frame_222.png written!
# opencv_frame_223.png written!
# opencv_frame_224.png written!
# opencv_frame_225.png written!
# opencv_frame_226.png written!
# opencv_frame_227.png written!
# opencv_frame_228.png written!
# opencv_frame_229.png written!
# opencv_frame_230.png written!
# opencv_frame_231.png written!
# opencv_frame_232.png written!
# opencv_frame_233.png written!
# opencv_frame_234.png written!
# opencv_frame_235.png written!
# opencv_frame_236.png written!
# opencv_frame_237.png written!
# opencv_frame_238.png written!
# opencv_frame_239.png written!
# opencv_frame_240.png written!
# opencv_frame_241.png written!
# opencv_frame_242.png written!
# opencv_frame_243.png written!
# opencv_frame_244.png written!
# opencv_frame_245.png written!
# opencv_frame_246.png written!
# opencv_frame_247.png written!
# opencv_frame_248.png written!
# opencv_frame_249.png written!
# opencv_frame_250.png written!
# opencv_frame_251.png written!
# opencv_frame_252.png written!
# opencv_frame_253.png written!
# opencv_frame_254.png written!
# opencv_frame_255.png written!
# opencv_frame_256.png written!
# opencv_frame_257.png written!
# opencv_frame_258.png written!
# opencv_frame_259.png written!
# opencv_frame_260.png written!
# opencv_frame_261.png written!
# opencv_frame_262.png written!
# opencv_frame_263.png written!
# opencv_frame_264.png written!
# opencv_frame_265.png written!
# opencv_frame_266.png written!
# opencv_frame_267.png written!
# opencv_frame_268.png written!
# opencv_frame_269.png written!
# opencv_frame_270.png written!
# opencv_frame_271.png written!
# opencv_frame_272.png written!
# opencv_frame_273.png written!
# opencv_frame_274.png written!
# opencv_frame_275.png written!
# opencv_frame_276.png written!
# opencv_frame_277.png written!
# opencv_frame_278.png written!
# opencv_frame_279.png written!
# opencv_frame_280.png written!
# opencv_frame_281.png written!
# opencv_frame_282.png written!
# opencv_frame_283.png written!
# opencv_frame_284.png written!
# opencv_frame_285.png written!
# opencv_frame_286.png written!
# opencv_frame_287.png written!
# opencv_frame_288.png written!
# opencv_frame_289.png written!
# opencv_frame_290.png written!
# opencv_frame_291.png written!
# opencv_frame_292.png written!
# opencv_frame_293.png written!
# opencv_frame_294.png written!
# opencv_frame_295.png written!
# opencv_frame_296.png written!
# opencv_frame_297.png written!
# opencv_frame_298.png written!
# opencv_frame_299.png written!
# opencv_frame_300.png written!
# opencv_frame_301.png written!
# opencv_frame_302.png written!
# opencv_frame_303.png written!
# opencv_frame_304.png written!
# opencv_frame_305.png written!
# opencv_frame_306.png written!
# opencv_frame_307.png written!
# opencv_frame_308.png written!
# opencv_frame_309.png written!
# opencv_frame_310.png written!
# opencv_frame_311.png written!
# opencv_frame_312.png written!
# opencv_frame_313.png written!
# opencv_frame_314.png written!
# opencv_frame_315.png written!
# opencv_frame_316.png written!
# opencv_frame_317.png written!
# opencv_frame_318.png written!
# opencv_frame_319.png written!
# opencv_frame_320.png written!
# opencv_frame_321.png written!
# opencv_frame_322.png written!
# opencv_frame_323.png written!
# opencv_frame_324.png written!
# opencv_frame_325.png written!
# opencv_frame_326.png written!
# opencv_frame_327.png written!
# opencv_frame_328.png written!
# opencv_frame_329.png written!
# opencv_frame_330.png written!
# opencv_frame_331.png written!
# opencv_frame_332.png written!
# opencv_frame_333.png written!
# opencv_frame_334.png written!
# opencv_frame_335.png written!
# opencv_frame_336.png written!
# opencv_frame_337.png written!
# opencv_frame_338.png written!
# opencv_frame_339.png written!
# opencv_frame_340.png written!
# opencv_frame_341.png written!
# opencv_frame_342.png written!
# opencv_frame_343.png written!
# opencv_frame_344.png written!
# opencv_frame_345.png written!
# opencv_frame_346.png written!
# opencv_frame_347.png written!
# opencv_frame_348.png written!
# opencv_frame_349.png written!
# opencv_frame_350.png written!
# opencv_frame_351.png written!
# opencv_frame_352.png written!
# opencv_frame_353.png written!
# opencv_frame_354.png written!
# opencv_frame_355.png written!
# opencv_frame_356.png written!
# opencv_frame_357.png written!
# opencv_frame_358.png written!
# opencv_frame_359.png written!
# opencv_frame_360.png written!
# opencv_frame_361.png written!
# opencv_frame_362.png written!
# opencv_frame_363.png written!
# opencv_frame_364.png written!
# opencv_frame_365.png written!
# opencv_frame_366.png written!
# opencv_frame_367.png written!
# opencv_frame_368.png written!
# opencv_frame_369.png written!
# opencv_frame_370.png written!
# opencv_frame_371.png written!
# opencv_frame_372.png written!
# opencv_frame_373.png written!
# opencv_frame_374.png written!
# opencv_frame_375.png written!
# opencv_frame_376.png written!
# opencv_frame_377.png written!
# opencv_frame_378.png written!
# opencv_frame_379.png written!
# opencv_frame_380.png written!
# opencv_frame_381.png written!
# opencv_frame_382.png written!
# opencv_frame_383.png written!
# opencv_frame_384.png written!
# opencv_frame_385.png written!
# opencv_frame_386.png written!
# opencv_frame_387.png written!
# opencv_frame_388.png written!
# opencv_frame_389.png written!
# opencv_frame_390.png written!
# opencv_frame_391.png written!
# opencv_frame_392.png written!
# opencv_frame_393.png written!
# opencv_frame_394.png written!
# opencv_frame_395.png written!
# opencv_frame_396.png written!
# opencv_frame_397.png written!
# opencv_frame_398.png written!
# opencv_frame_399.png written!
# opencv_frame_400.png written!
# opencv_frame_401.png written!
# opencv_frame_402.png written!
# opencv_frame_403.png written!
# opencv_frame_404.png written!
# opencv_frame_405.png written!
# opencv_frame_406.png written!
# opencv_frame_407.png written!
# opencv_frame_408.png written!
# opencv_frame_409.png written!
# opencv_frame_410.png written!
# opencv_frame_411.png written!
# opencv_frame_412.png written!
# opencv_frame_413.png written!
# opencv_frame_414.png written!
# opencv_frame_415.png written!
# opencv_frame_416.png written!
# opencv_frame_417.png written!
# opencv_frame_418.png written!
# opencv_frame_419.png written!
# opencv_frame_420.png written!
# opencv_frame_421.png written!
# opencv_frame_422.png written!
# opencv_frame_423.png written!
# opencv_frame_424.png written!
# opencv_frame_425.png written!
# opencv_frame_426.png written!
# opencv_frame_427.png written!
# opencv_frame_428.png written!
# opencv_frame_429.png written!
# opencv_frame_430.png written!
# opencv_frame_431.png written!
# opencv_frame_432.png written!
# opencv_frame_433.png written!
# opencv_frame_434.png written!
# opencv_frame_435.png written!
# opencv_frame_436.png written!
# opencv_frame_437.png written!
# opencv_frame_438.png written!
# opencv_frame_439.png written!
# opencv_frame_440.png written!
# opencv_frame_441.png written!
# opencv_frame_442.png written!
# opencv_frame_443.png written!
# opencv_frame_444.png written!
# opencv_frame_445.png written!
# opencv_frame_446.png written!
# opencv_frame_447.png written!
# opencv_frame_448.png written!
# opencv_frame_449.png written!
# opencv_frame_450.png written!
# opencv_frame_451.png written!
# opencv_frame_452.png written!
# opencv_frame_453.png written!
# opencv_frame_454.png written!
# opencv_frame_455.png written!
# opencv_frame_456.png written!
# opencv_frame_457.png written!
# opencv_frame_458.png written!
# opencv_frame_459.png written!
# opencv_frame_460.png written!
# opencv_frame_461.png written!
# opencv_frame_462.png written!
# opencv_frame_463.png written!
# opencv_frame_464.png written!
# opencv_frame_465.png written!
# opencv_frame_466.png written!
# opencv_frame_467.png written!
# opencv_frame_468.png written!
# opencv_frame_469.png written!
# opencv_frame_470.png written!
# opencv_frame_471.png written!
# opencv_frame_472.png written!
# opencv_frame_473.png written!
# opencv_frame_474.png written!
# opencv_frame_475.png written!
# opencv_frame_476.png written!
# opencv_frame_477.png written!
# opencv_frame_478.png written!
# opencv_frame_479.png written!
# opencv_frame_480.png written!
# opencv_frame_481.png written!
# opencv_frame_482.png written!
# opencv_frame_483.png written!
# opencv_frame_484.png written!
# opencv_frame_485.png written!
# opencv_frame_486.png written!
# opencv_frame_487.png written!
# opencv_frame_488.png written!
# opencv_frame_489.png written!
# opencv_frame_490.png written!
# opencv_frame_491.png written!
# opencv_frame_492.png written!
# opencv_frame_493.png written!
# opencv_frame_494.png written!
# opencv_frame_495.png written!
# opencv_frame_496.png written!
# opencv_frame_497.png written!
# opencv_frame_498.png written!
# opencv_frame_499.png written!
# Escape hit, closing...

# %%
get_images("rock")
# Out:
# Couldn't make a directory
# opencv_frame_0.png written!
# opencv_frame_1.png written!
# opencv_frame_2.png written!
# opencv_frame_3.png written!
# opencv_frame_4.png written!
# opencv_frame_5.png written!
# opencv_frame_6.png written!
# opencv_frame_7.png written!
# opencv_frame_8.png written!
# opencv_frame_9.png written!
# opencv_frame_10.png written!
# opencv_frame_11.png written!
# opencv_frame_12.png written!
# opencv_frame_13.png written!
# opencv_frame_14.png written!
# opencv_frame_15.png written!
# opencv_frame_16.png written!
# opencv_frame_17.png written!
# opencv_frame_18.png written!
# opencv_frame_19.png written!
# opencv_frame_20.png written!
# opencv_frame_21.png written!
# opencv_frame_22.png written!
# opencv_frame_23.png written!
# opencv_frame_24.png written!
# opencv_frame_25.png written!
# opencv_frame_26.png written!
# opencv_frame_27.png written!
# opencv_frame_28.png written!
# opencv_frame_29.png written!
# opencv_frame_30.png written!
# opencv_frame_31.png written!
# opencv_frame_32.png written!
# opencv_frame_33.png written!
# opencv_frame_34.png written!
# opencv_frame_35.png written!
# opencv_frame_36.png written!
# opencv_frame_37.png written!
# opencv_frame_38.png written!
# opencv_frame_39.png written!
# opencv_frame_40.png written!
# opencv_frame_41.png written!
# opencv_frame_42.png written!
# opencv_frame_43.png written!
# opencv_frame_44.png written!
# opencv_frame_45.png written!
# opencv_frame_46.png written!
# opencv_frame_47.png written!
# opencv_frame_48.png written!
# opencv_frame_49.png written!
# opencv_frame_50.png written!
# opencv_frame_51.png written!
# opencv_frame_52.png written!
# opencv_frame_53.png written!
# opencv_frame_54.png written!
# opencv_frame_55.png written!
# opencv_frame_56.png written!
# opencv_frame_57.png written!
# opencv_frame_58.png written!
# opencv_frame_59.png written!
# opencv_frame_60.png written!
# opencv_frame_61.png written!
# opencv_frame_62.png written!
# opencv_frame_63.png written!
# opencv_frame_64.png written!
# opencv_frame_65.png written!
# opencv_frame_66.png written!
# opencv_frame_67.png written!
# opencv_frame_68.png written!
# opencv_frame_69.png written!
# opencv_frame_70.png written!
# opencv_frame_71.png written!
# opencv_frame_72.png written!
# opencv_frame_73.png written!
# opencv_frame_74.png written!
# opencv_frame_75.png written!
# opencv_frame_76.png written!
# opencv_frame_77.png written!
# opencv_frame_78.png written!
# opencv_frame_79.png written!
# opencv_frame_80.png written!
# opencv_frame_81.png written!
# opencv_frame_82.png written!
# opencv_frame_83.png written!
# opencv_frame_84.png written!
# opencv_frame_85.png written!
# opencv_frame_86.png written!
# opencv_frame_87.png written!
# opencv_frame_88.png written!
# opencv_frame_89.png written!
# opencv_frame_90.png written!
# opencv_frame_91.png written!
# opencv_frame_92.png written!
# opencv_frame_93.png written!
# opencv_frame_94.png written!
# opencv_frame_95.png written!
# opencv_frame_96.png written!
# opencv_frame_97.png written!
# opencv_frame_98.png written!
# opencv_frame_99.png written!
# opencv_frame_100.png written!
# opencv_frame_101.png written!
# opencv_frame_102.png written!
# opencv_frame_103.png written!
# opencv_frame_104.png written!
# opencv_frame_105.png written!
# opencv_frame_106.png written!
# opencv_frame_107.png written!
# opencv_frame_108.png written!
# opencv_frame_109.png written!
# opencv_frame_110.png written!
# opencv_frame_111.png written!
# opencv_frame_112.png written!
# opencv_frame_113.png written!
# opencv_frame_114.png written!
# opencv_frame_115.png written!
# opencv_frame_116.png written!
# opencv_frame_117.png written!
# opencv_frame_118.png written!
# opencv_frame_119.png written!
# opencv_frame_120.png written!
# opencv_frame_121.png written!
# opencv_frame_122.png written!
# opencv_frame_123.png written!
# opencv_frame_124.png written!
# opencv_frame_125.png written!
# opencv_frame_126.png written!
# opencv_frame_127.png written!
# opencv_frame_128.png written!
# opencv_frame_129.png written!
# opencv_frame_130.png written!
# opencv_frame_131.png written!
# opencv_frame_132.png written!
# opencv_frame_133.png written!
# opencv_frame_134.png written!
# opencv_frame_135.png written!
# opencv_frame_136.png written!
# opencv_frame_137.png written!
# opencv_frame_138.png written!
# opencv_frame_139.png written!
# opencv_frame_140.png written!
# opencv_frame_141.png written!
# opencv_frame_142.png written!
# opencv_frame_143.png written!
# opencv_frame_144.png written!
# opencv_frame_145.png written!
# opencv_frame_146.png written!
# opencv_frame_147.png written!
# opencv_frame_148.png written!
# opencv_frame_149.png written!
# opencv_frame_150.png written!
# opencv_frame_151.png written!
# opencv_frame_152.png written!
# opencv_frame_153.png written!
# opencv_frame_154.png written!
# opencv_frame_155.png written!
# opencv_frame_156.png written!
# opencv_frame_157.png written!
# opencv_frame_158.png written!
# opencv_frame_159.png written!
# opencv_frame_160.png written!
# opencv_frame_161.png written!
# opencv_frame_162.png written!
# opencv_frame_163.png written!
# opencv_frame_164.png written!
# opencv_frame_165.png written!
# opencv_frame_166.png written!
# opencv_frame_167.png written!
# opencv_frame_168.png written!
# opencv_frame_169.png written!
# opencv_frame_170.png written!
# opencv_frame_171.png written!
# opencv_frame_172.png written!
# opencv_frame_173.png written!
# opencv_frame_174.png written!
# opencv_frame_175.png written!
# opencv_frame_176.png written!
# opencv_frame_177.png written!
# opencv_frame_178.png written!
# opencv_frame_179.png written!
# opencv_frame_180.png written!
# opencv_frame_181.png written!
# opencv_frame_182.png written!
# opencv_frame_183.png written!
# opencv_frame_184.png written!
# opencv_frame_185.png written!
# opencv_frame_186.png written!
# opencv_frame_187.png written!
# opencv_frame_188.png written!
# opencv_frame_189.png written!
# opencv_frame_190.png written!
# opencv_frame_191.png written!
# opencv_frame_192.png written!
# opencv_frame_193.png written!
# opencv_frame_194.png written!
# opencv_frame_195.png written!
# opencv_frame_196.png written!
# opencv_frame_197.png written!
# opencv_frame_198.png written!
# opencv_frame_199.png written!
# opencv_frame_200.png written!
# opencv_frame_201.png written!
# opencv_frame_202.png written!
# opencv_frame_203.png written!
# opencv_frame_204.png written!
# opencv_frame_205.png written!
# opencv_frame_206.png written!
# opencv_frame_207.png written!
# opencv_frame_208.png written!
# opencv_frame_209.png written!
# opencv_frame_210.png written!
# opencv_frame_211.png written!
# opencv_frame_212.png written!
# opencv_frame_213.png written!
# opencv_frame_214.png written!
# opencv_frame_215.png written!
# opencv_frame_216.png written!
# opencv_frame_217.png written!
# opencv_frame_218.png written!
# opencv_frame_219.png written!
# opencv_frame_220.png written!
# opencv_frame_221.png written!
# opencv_frame_222.png written!
# opencv_frame_223.png written!
# opencv_frame_224.png written!
# opencv_frame_225.png written!
# opencv_frame_226.png written!
# opencv_frame_227.png written!
# opencv_frame_228.png written!
# opencv_frame_229.png written!
# opencv_frame_230.png written!
# opencv_frame_231.png written!
# opencv_frame_232.png written!
# opencv_frame_233.png written!
# opencv_frame_234.png written!
# opencv_frame_235.png written!
# opencv_frame_236.png written!
# opencv_frame_237.png written!
# opencv_frame_238.png written!
# opencv_frame_239.png written!
# opencv_frame_240.png written!
# opencv_frame_241.png written!
# opencv_frame_242.png written!
# opencv_frame_243.png written!
# opencv_frame_244.png written!
# opencv_frame_245.png written!
# opencv_frame_246.png written!
# opencv_frame_247.png written!
# opencv_frame_248.png written!
# opencv_frame_249.png written!
# opencv_frame_250.png written!
# opencv_frame_251.png written!
# opencv_frame_252.png written!
# opencv_frame_253.png written!
# opencv_frame_254.png written!
# opencv_frame_255.png written!
# opencv_frame_256.png written!
# opencv_frame_257.png written!
# opencv_frame_258.png written!
# opencv_frame_259.png written!
# opencv_frame_260.png written!
# opencv_frame_261.png written!
# opencv_frame_262.png written!
# opencv_frame_263.png written!
# opencv_frame_264.png written!
# opencv_frame_265.png written!
# opencv_frame_266.png written!
# opencv_frame_267.png written!
# opencv_frame_268.png written!
# opencv_frame_269.png written!
# opencv_frame_270.png written!
# opencv_frame_271.png written!
# opencv_frame_272.png written!
# opencv_frame_273.png written!
# opencv_frame_274.png written!
# opencv_frame_275.png written!
# opencv_frame_276.png written!
# opencv_frame_277.png written!
# opencv_frame_278.png written!
# opencv_frame_279.png written!
# opencv_frame_280.png written!
# opencv_frame_281.png written!
# opencv_frame_282.png written!
# opencv_frame_283.png written!
# opencv_frame_284.png written!
# opencv_frame_285.png written!
# opencv_frame_286.png written!
# opencv_frame_287.png written!
# opencv_frame_288.png written!
# opencv_frame_289.png written!
# opencv_frame_290.png written!
# opencv_frame_291.png written!
# opencv_frame_292.png written!
# opencv_frame_293.png written!
# opencv_frame_294.png written!
# opencv_frame_295.png written!
# opencv_frame_296.png written!
# opencv_frame_297.png written!
# opencv_frame_298.png written!
# opencv_frame_299.png written!
# opencv_frame_300.png written!
# opencv_frame_301.png written!
# opencv_frame_302.png written!
# opencv_frame_303.png written!
# opencv_frame_304.png written!
# opencv_frame_305.png written!
# opencv_frame_306.png written!
# opencv_frame_307.png written!
# opencv_frame_308.png written!
# opencv_frame_309.png written!
# opencv_frame_310.png written!
# opencv_frame_311.png written!
# opencv_frame_312.png written!
# opencv_frame_313.png written!
# opencv_frame_314.png written!
# opencv_frame_315.png written!
# opencv_frame_316.png written!
# opencv_frame_317.png written!
# opencv_frame_318.png written!
# opencv_frame_319.png written!
# opencv_frame_320.png written!
# opencv_frame_321.png written!
# opencv_frame_322.png written!
# opencv_frame_323.png written!
# opencv_frame_324.png written!
# opencv_frame_325.png written!
# opencv_frame_326.png written!
# opencv_frame_327.png written!
# opencv_frame_328.png written!
# opencv_frame_329.png written!
# opencv_frame_330.png written!
# opencv_frame_331.png written!
# opencv_frame_332.png written!
# opencv_frame_333.png written!
# opencv_frame_334.png written!
# opencv_frame_335.png written!
# opencv_frame_336.png written!
# opencv_frame_337.png written!
# opencv_frame_338.png written!
# opencv_frame_339.png written!
# opencv_frame_340.png written!
# opencv_frame_341.png written!
# opencv_frame_342.png written!
# opencv_frame_343.png written!
# opencv_frame_344.png written!
# opencv_frame_345.png written!
# opencv_frame_346.png written!
# opencv_frame_347.png written!
# opencv_frame_348.png written!
# opencv_frame_349.png written!
# opencv_frame_350.png written!
# opencv_frame_351.png written!
# opencv_frame_352.png written!
# opencv_frame_353.png written!
# opencv_frame_354.png written!
# opencv_frame_355.png written!
# opencv_frame_356.png written!
# opencv_frame_357.png written!
# opencv_frame_358.png written!
# opencv_frame_359.png written!
# opencv_frame_360.png written!
# opencv_frame_361.png written!
# opencv_frame_362.png written!
# opencv_frame_363.png written!
# opencv_frame_364.png written!
# opencv_frame_365.png written!
# opencv_frame_366.png written!
# opencv_frame_367.png written!
# opencv_frame_368.png written!
# opencv_frame_369.png written!
# opencv_frame_370.png written!
# opencv_frame_371.png written!
# opencv_frame_372.png written!
# opencv_frame_373.png written!
# opencv_frame_374.png written!
# opencv_frame_375.png written!
# opencv_frame_376.png written!
# opencv_frame_377.png written!
# opencv_frame_378.png written!
# opencv_frame_379.png written!
# opencv_frame_380.png written!
# opencv_frame_381.png written!
# opencv_frame_382.png written!
# opencv_frame_383.png written!
# opencv_frame_384.png written!
# opencv_frame_385.png written!
# opencv_frame_386.png written!
# opencv_frame_387.png written!
# opencv_frame_388.png written!
# opencv_frame_389.png written!
# opencv_frame_390.png written!
# opencv_frame_391.png written!
# opencv_frame_392.png written!
# opencv_frame_393.png written!
# opencv_frame_394.png written!
# opencv_frame_395.png written!
# opencv_frame_396.png written!
# opencv_frame_397.png written!
# opencv_frame_398.png written!
# opencv_frame_399.png written!
# opencv_frame_400.png written!
# opencv_frame_401.png written!
# opencv_frame_402.png written!
# opencv_frame_403.png written!
# opencv_frame_404.png written!
# opencv_frame_405.png written!
# opencv_frame_406.png written!
# opencv_frame_407.png written!
# opencv_frame_408.png written!
# opencv_frame_409.png written!
# opencv_frame_410.png written!
# opencv_frame_411.png written!
# opencv_frame_412.png written!
# opencv_frame_413.png written!
# opencv_frame_414.png written!
# opencv_frame_415.png written!
# opencv_frame_416.png written!
# opencv_frame_417.png written!
# opencv_frame_418.png written!
# opencv_frame_419.png written!
# opencv_frame_420.png written!
# opencv_frame_421.png written!
# opencv_frame_422.png written!
# opencv_frame_423.png written!
# opencv_frame_424.png written!
# opencv_frame_425.png written!
# opencv_frame_426.png written!
# opencv_frame_427.png written!
# opencv_frame_428.png written!
# opencv_frame_429.png written!
# opencv_frame_430.png written!
# opencv_frame_431.png written!
# opencv_frame_432.png written!
# opencv_frame_433.png written!
# opencv_frame_434.png written!
# opencv_frame_435.png written!
# opencv_frame_436.png written!
# opencv_frame_437.png written!
# opencv_frame_438.png written!
# opencv_frame_439.png written!
# opencv_frame_440.png written!
# opencv_frame_441.png written!
# opencv_frame_442.png written!
# opencv_frame_443.png written!
# opencv_frame_444.png written!
# opencv_frame_445.png written!
# opencv_frame_446.png written!
# opencv_frame_447.png written!
# opencv_frame_448.png written!
# opencv_frame_449.png written!
# opencv_frame_450.png written!
# opencv_frame_451.png written!
# opencv_frame_452.png written!
# opencv_frame_453.png written!
# opencv_frame_454.png written!
# opencv_frame_455.png written!
# opencv_frame_456.png written!
# opencv_frame_457.png written!
# opencv_frame_458.png written!
# opencv_frame_459.png written!
# opencv_frame_460.png written!
# opencv_frame_461.png written!
# opencv_frame_462.png written!
# opencv_frame_463.png written!
# opencv_frame_464.png written!
# opencv_frame_465.png written!
# opencv_frame_466.png written!
# opencv_frame_467.png written!
# opencv_frame_468.png written!
# opencv_frame_469.png written!
# opencv_frame_470.png written!
# opencv_frame_471.png written!
# opencv_frame_472.png written!
# opencv_frame_473.png written!
# opencv_frame_474.png written!
# opencv_frame_475.png written!
# opencv_frame_476.png written!
# opencv_frame_477.png written!
# opencv_frame_478.png written!
# opencv_frame_479.png written!
# opencv_frame_480.png written!
# opencv_frame_481.png written!
# opencv_frame_482.png written!
# opencv_frame_483.png written!
# opencv_frame_484.png written!
# opencv_frame_485.png written!
# opencv_frame_486.png written!
# opencv_frame_487.png written!
# opencv_frame_488.png written!
# opencv_frame_489.png written!
# opencv_frame_490.png written!
# opencv_frame_491.png written!
# opencv_frame_492.png written!
# opencv_frame_493.png written!
# opencv_frame_494.png written!
# opencv_frame_495.png written!
# opencv_frame_496.png written!
# opencv_frame_497.png written!
# opencv_frame_498.png written!
# opencv_frame_499.png written!
# opencv_frame_500.png written!
# opencv_frame_501.png written!
# opencv_frame_502.png written!
# opencv_frame_503.png written!
# opencv_frame_504.png written!
# opencv_frame_505.png written!
# opencv_frame_506.png written!
# opencv_frame_507.png written!
# opencv_frame_508.png written!
# opencv_frame_509.png written!
# opencv_frame_510.png written!
# opencv_frame_511.png written!
# opencv_frame_512.png written!
# opencv_frame_513.png written!
# opencv_frame_514.png written!
# opencv_frame_515.png written!
# Escape hit, closing...

# %%
get_images("empty")
# Out:
# Couldn't make a directory
# opencv_frame_0.png written!
# opencv_frame_1.png written!
# opencv_frame_2.png written!
# opencv_frame_3.png written!
# opencv_frame_4.png written!
# opencv_frame_5.png written!
# opencv_frame_6.png written!
# opencv_frame_7.png written!
# opencv_frame_8.png written!
# opencv_frame_9.png written!
# opencv_frame_10.png written!
# opencv_frame_11.png written!
# opencv_frame_12.png written!
# opencv_frame_13.png written!
# opencv_frame_14.png written!
# opencv_frame_15.png written!
# opencv_frame_16.png written!
# opencv_frame_17.png written!
# opencv_frame_18.png written!
# opencv_frame_19.png written!
# opencv_frame_20.png written!
# opencv_frame_21.png written!
# opencv_frame_22.png written!
# opencv_frame_23.png written!
# opencv_frame_24.png written!
# opencv_frame_25.png written!
# opencv_frame_26.png written!
# opencv_frame_27.png written!
# opencv_frame_28.png written!
# opencv_frame_29.png written!
# opencv_frame_30.png written!
# opencv_frame_31.png written!
# opencv_frame_32.png written!
# opencv_frame_33.png written!
# opencv_frame_34.png written!
# opencv_frame_35.png written!
# opencv_frame_36.png written!
# opencv_frame_37.png written!
# opencv_frame_38.png written!
# opencv_frame_39.png written!
# opencv_frame_40.png written!
# opencv_frame_41.png written!
# opencv_frame_42.png written!
# opencv_frame_43.png written!
# opencv_frame_44.png written!
# opencv_frame_45.png written!
# opencv_frame_46.png written!
# opencv_frame_47.png written!
# opencv_frame_48.png written!
# opencv_frame_49.png written!
# opencv_frame_50.png written!
# opencv_frame_51.png written!
# opencv_frame_52.png written!
# opencv_frame_53.png written!
# opencv_frame_54.png written!
# opencv_frame_55.png written!
# opencv_frame_56.png written!
# opencv_frame_57.png written!
# opencv_frame_58.png written!
# opencv_frame_59.png written!
# opencv_frame_60.png written!
# opencv_frame_61.png written!
# opencv_frame_62.png written!
# opencv_frame_63.png written!
# opencv_frame_64.png written!
# opencv_frame_65.png written!
# opencv_frame_66.png written!
# opencv_frame_67.png written!
# opencv_frame_68.png written!
# opencv_frame_69.png written!
# opencv_frame_70.png written!
# opencv_frame_71.png written!
# opencv_frame_72.png written!
# opencv_frame_73.png written!
# opencv_frame_74.png written!
# opencv_frame_75.png written!
# opencv_frame_76.png written!
# opencv_frame_77.png written!
# opencv_frame_78.png written!
# opencv_frame_79.png written!
# opencv_frame_80.png written!
# opencv_frame_81.png written!
# opencv_frame_82.png written!
# opencv_frame_83.png written!
# opencv_frame_84.png written!
# opencv_frame_85.png written!
# opencv_frame_86.png written!
# opencv_frame_87.png written!
# opencv_frame_88.png written!
# opencv_frame_89.png written!
# opencv_frame_90.png written!
# opencv_frame_91.png written!
# opencv_frame_92.png written!
# opencv_frame_93.png written!
# opencv_frame_94.png written!
# opencv_frame_95.png written!
# opencv_frame_96.png written!
# opencv_frame_97.png written!
# opencv_frame_98.png written!
# opencv_frame_99.png written!
# opencv_frame_100.png written!
# opencv_frame_101.png written!
# opencv_frame_102.png written!
# opencv_frame_103.png written!
# opencv_frame_104.png written!
# opencv_frame_105.png written!
# opencv_frame_106.png written!
# opencv_frame_107.png written!
# opencv_frame_108.png written!
# opencv_frame_109.png written!
# opencv_frame_110.png written!
# opencv_frame_111.png written!
# opencv_frame_112.png written!
# opencv_frame_113.png written!
# opencv_frame_114.png written!
# opencv_frame_115.png written!
# opencv_frame_116.png written!
# opencv_frame_117.png written!
# opencv_frame_118.png written!
# opencv_frame_119.png written!
# opencv_frame_120.png written!
# opencv_frame_121.png written!
# opencv_frame_122.png written!
# opencv_frame_123.png written!
# opencv_frame_124.png written!
# opencv_frame_125.png written!
# opencv_frame_126.png written!
# opencv_frame_127.png written!
# opencv_frame_128.png written!
# opencv_frame_129.png written!
# opencv_frame_130.png written!
# opencv_frame_131.png written!
# opencv_frame_132.png written!
# opencv_frame_133.png written!
# opencv_frame_134.png written!
# opencv_frame_135.png written!
# opencv_frame_136.png written!
# opencv_frame_137.png written!
# opencv_frame_138.png written!
# opencv_frame_139.png written!
# opencv_frame_140.png written!
# opencv_frame_141.png written!
# opencv_frame_142.png written!
# opencv_frame_143.png written!
# opencv_frame_144.png written!
# opencv_frame_145.png written!
# opencv_frame_146.png written!
# opencv_frame_147.png written!
# opencv_frame_148.png written!
# opencv_frame_149.png written!
# opencv_frame_150.png written!
# opencv_frame_151.png written!
# opencv_frame_152.png written!
# opencv_frame_153.png written!
# opencv_frame_154.png written!
# opencv_frame_155.png written!
# opencv_frame_156.png written!
# opencv_frame_157.png written!
# opencv_frame_158.png written!
# opencv_frame_159.png written!
# opencv_frame_160.png written!
# opencv_frame_161.png written!
# opencv_frame_162.png written!
# opencv_frame_163.png written!
# opencv_frame_164.png written!
# opencv_frame_165.png written!
# opencv_frame_166.png written!
# opencv_frame_167.png written!
# opencv_frame_168.png written!
# opencv_frame_169.png written!
# opencv_frame_170.png written!
# opencv_frame_171.png written!
# opencv_frame_172.png written!
# opencv_frame_173.png written!
# opencv_frame_174.png written!
# opencv_frame_175.png written!
# opencv_frame_176.png written!
# opencv_frame_177.png written!
# opencv_frame_178.png written!
# opencv_frame_179.png written!
# opencv_frame_180.png written!
# opencv_frame_181.png written!
# opencv_frame_182.png written!
# opencv_frame_183.png written!
# opencv_frame_184.png written!
# opencv_frame_185.png written!
# opencv_frame_186.png written!
# opencv_frame_187.png written!
# opencv_frame_188.png written!
# opencv_frame_189.png written!
# opencv_frame_190.png written!
# opencv_frame_191.png written!
# opencv_frame_192.png written!
# opencv_frame_193.png written!
# opencv_frame_194.png written!
# opencv_frame_195.png written!
# opencv_frame_196.png written!
# opencv_frame_197.png written!
# opencv_frame_198.png written!
# opencv_frame_199.png written!
# opencv_frame_200.png written!
# opencv_frame_201.png written!
# opencv_frame_202.png written!
# opencv_frame_203.png written!
# opencv_frame_204.png written!
# opencv_frame_205.png written!
# opencv_frame_206.png written!
# opencv_frame_207.png written!
# opencv_frame_208.png written!
# opencv_frame_209.png written!
# opencv_frame_210.png written!
# opencv_frame_211.png written!
# opencv_frame_212.png written!
# opencv_frame_213.png written!
# opencv_frame_214.png written!
# opencv_frame_215.png written!
# opencv_frame_216.png written!
# opencv_frame_217.png written!
# opencv_frame_218.png written!
# opencv_frame_219.png written!
# opencv_frame_220.png written!
# opencv_frame_221.png written!
# opencv_frame_222.png written!
# opencv_frame_223.png written!
# opencv_frame_224.png written!
# opencv_frame_225.png written!
# opencv_frame_226.png written!
# opencv_frame_227.png written!
# opencv_frame_228.png written!
# opencv_frame_229.png written!
# opencv_frame_230.png written!
# opencv_frame_231.png written!
# opencv_frame_232.png written!
# opencv_frame_233.png written!
# opencv_frame_234.png written!
# opencv_frame_235.png written!
# opencv_frame_236.png written!
# opencv_frame_237.png written!
# opencv_frame_238.png written!
# opencv_frame_239.png written!
# opencv_frame_240.png written!
# opencv_frame_241.png written!
# opencv_frame_242.png written!
# opencv_frame_243.png written!
# opencv_frame_244.png written!
# opencv_frame_245.png written!
# opencv_frame_246.png written!
# opencv_frame_247.png written!
# opencv_frame_248.png written!
# opencv_frame_249.png written!
# opencv_frame_250.png written!
# opencv_frame_251.png written!
# opencv_frame_252.png written!
# opencv_frame_253.png written!
# opencv_frame_254.png written!
# opencv_frame_255.png written!
# opencv_frame_256.png written!
# opencv_frame_257.png written!
# opencv_frame_258.png written!
# opencv_frame_259.png written!
# opencv_frame_260.png written!
# opencv_frame_261.png written!
# opencv_frame_262.png written!
# opencv_frame_263.png written!
# opencv_frame_264.png written!
# opencv_frame_265.png written!
# opencv_frame_266.png written!
# opencv_frame_267.png written!
# opencv_frame_268.png written!
# opencv_frame_269.png written!
# opencv_frame_270.png written!
# opencv_frame_271.png written!
# opencv_frame_272.png written!
# opencv_frame_273.png written!
# opencv_frame_274.png written!
# opencv_frame_275.png written!
# opencv_frame_276.png written!
# opencv_frame_277.png written!
# opencv_frame_278.png written!
# opencv_frame_279.png written!
# opencv_frame_280.png written!
# opencv_frame_281.png written!
# opencv_frame_282.png written!
# opencv_frame_283.png written!
# opencv_frame_284.png written!
# opencv_frame_285.png written!
# opencv_frame_286.png written!
# opencv_frame_287.png written!
# opencv_frame_288.png written!
# opencv_frame_289.png written!
# opencv_frame_290.png written!
# opencv_frame_291.png written!
# opencv_frame_292.png written!
# opencv_frame_293.png written!
# opencv_frame_294.png written!
# opencv_frame_295.png written!
# opencv_frame_296.png written!
# opencv_frame_297.png written!
# opencv_frame_298.png written!
# opencv_frame_299.png written!
# opencv_frame_300.png written!
# opencv_frame_301.png written!
# opencv_frame_302.png written!
# opencv_frame_303.png written!
# opencv_frame_304.png written!
# opencv_frame_305.png written!
# opencv_frame_306.png written!
# opencv_frame_307.png written!
# opencv_frame_308.png written!
# opencv_frame_309.png written!
# opencv_frame_310.png written!
# opencv_frame_311.png written!
# opencv_frame_312.png written!
# opencv_frame_313.png written!
# opencv_frame_314.png written!
# opencv_frame_315.png written!
# opencv_frame_316.png written!
# opencv_frame_317.png written!
# opencv_frame_318.png written!
# opencv_frame_319.png written!
# opencv_frame_320.png written!
# opencv_frame_321.png written!
# opencv_frame_322.png written!
# opencv_frame_323.png written!
# opencv_frame_324.png written!
# opencv_frame_325.png written!
# opencv_frame_326.png written!
# opencv_frame_327.png written!
# opencv_frame_328.png written!
# opencv_frame_329.png written!
# opencv_frame_330.png written!
# opencv_frame_331.png written!
# opencv_frame_332.png written!
# opencv_frame_333.png written!
# opencv_frame_334.png written!
# opencv_frame_335.png written!
# opencv_frame_336.png written!
# opencv_frame_337.png written!
# opencv_frame_338.png written!
# opencv_frame_339.png written!
# opencv_frame_340.png written!
# opencv_frame_341.png written!
# opencv_frame_342.png written!
# opencv_frame_343.png written!
# opencv_frame_344.png written!
# opencv_frame_345.png written!
# opencv_frame_346.png written!
# opencv_frame_347.png written!
# opencv_frame_348.png written!
# opencv_frame_349.png written!
# opencv_frame_350.png written!
# opencv_frame_351.png written!
# opencv_frame_352.png written!
# opencv_frame_353.png written!
# opencv_frame_354.png written!
# opencv_frame_355.png written!
# opencv_frame_356.png written!
# opencv_frame_357.png written!
# opencv_frame_358.png written!
# opencv_frame_359.png written!
# opencv_frame_360.png written!
# opencv_frame_361.png written!
# opencv_frame_362.png written!
# opencv_frame_363.png written!
# opencv_frame_364.png written!
# opencv_frame_365.png written!
# opencv_frame_366.png written!
# opencv_frame_367.png written!
# opencv_frame_368.png written!
# opencv_frame_369.png written!
# opencv_frame_370.png written!
# opencv_frame_371.png written!
# opencv_frame_372.png written!
# opencv_frame_373.png written!
# opencv_frame_374.png written!
# opencv_frame_375.png written!
# opencv_frame_376.png written!
# opencv_frame_377.png written!
# opencv_frame_378.png written!
# opencv_frame_379.png written!
# opencv_frame_380.png written!
# opencv_frame_381.png written!
# opencv_frame_382.png written!
# opencv_frame_383.png written!
# opencv_frame_384.png written!
# opencv_frame_385.png written!
# opencv_frame_386.png written!
# opencv_frame_387.png written!
# opencv_frame_388.png written!
# opencv_frame_389.png written!
# opencv_frame_390.png written!
# opencv_frame_391.png written!
# opencv_frame_392.png written!
# opencv_frame_393.png written!
# opencv_frame_394.png written!
# opencv_frame_395.png written!
# opencv_frame_396.png written!
# opencv_frame_397.png written!
# opencv_frame_398.png written!
# opencv_frame_399.png written!
# opencv_frame_400.png written!
# opencv_frame_401.png written!
# opencv_frame_402.png written!
# opencv_frame_403.png written!
# opencv_frame_404.png written!
# opencv_frame_405.png written!
# opencv_frame_406.png written!
# opencv_frame_407.png written!
# opencv_frame_408.png written!
# opencv_frame_409.png written!
# opencv_frame_410.png written!
# opencv_frame_411.png written!
# opencv_frame_412.png written!
# opencv_frame_413.png written!
# opencv_frame_414.png written!
# opencv_frame_415.png written!
# opencv_frame_416.png written!
# opencv_frame_417.png written!
# opencv_frame_418.png written!
# opencv_frame_419.png written!
# opencv_frame_420.png written!
# opencv_frame_421.png written!
# opencv_frame_422.png written!
# opencv_frame_423.png written!
# opencv_frame_424.png written!
# opencv_frame_425.png written!
# opencv_frame_426.png written!
# opencv_frame_427.png written!
# opencv_frame_428.png written!
# opencv_frame_429.png written!
# opencv_frame_430.png written!
# opencv_frame_431.png written!
# opencv_frame_432.png written!
# opencv_frame_433.png written!
# opencv_frame_434.png written!
# opencv_frame_435.png written!
# opencv_frame_436.png written!
# opencv_frame_437.png written!
# opencv_frame_438.png written!
# opencv_frame_439.png written!
# opencv_frame_440.png written!
# opencv_frame_441.png written!
# opencv_frame_442.png written!
# opencv_frame_443.png written!
# opencv_frame_444.png written!
# opencv_frame_445.png written!
# opencv_frame_446.png written!
# opencv_frame_447.png written!
# opencv_frame_448.png written!
# opencv_frame_449.png written!
# opencv_frame_450.png written!
# opencv_frame_451.png written!
# opencv_frame_452.png written!
# opencv_frame_453.png written!
# opencv_frame_454.png written!
# opencv_frame_455.png written!
# opencv_frame_456.png written!
# opencv_frame_457.png written!
# opencv_frame_458.png written!
# opencv_frame_459.png written!
# opencv_frame_460.png written!
# opencv_frame_461.png written!
# opencv_frame_462.png written!
# opencv_frame_463.png written!
# opencv_frame_464.png written!
# opencv_frame_465.png written!
# opencv_frame_466.png written!
# opencv_frame_467.png written!
# opencv_frame_468.png written!
# opencv_frame_469.png written!
# opencv_frame_470.png written!
# opencv_frame_471.png written!
# opencv_frame_472.png written!
# opencv_frame_473.png written!
# opencv_frame_474.png written!
# opencv_frame_475.png written!
# opencv_frame_476.png written!
# opencv_frame_477.png written!
# opencv_frame_478.png written!
# opencv_frame_479.png written!
# opencv_frame_480.png written!
# opencv_frame_481.png written!
# opencv_frame_482.png written!
# opencv_frame_483.png written!
# opencv_frame_484.png written!
# opencv_frame_485.png written!
# opencv_frame_486.png written!
# opencv_frame_487.png written!
# opencv_frame_488.png written!
# opencv_frame_489.png written!
# opencv_frame_490.png written!
# opencv_frame_491.png written!
# opencv_frame_492.png written!
# opencv_frame_493.png written!
# opencv_frame_494.png written!
# opencv_frame_495.png written!
# opencv_frame_496.png written!
# opencv_frame_497.png written!
# opencv_frame_498.png written!
# opencv_frame_499.png written!
# Escape hit, closing...

# %%
get_images("spock")
# Out:
# opencv_frame_0.png written!
# opencv_frame_1.png written!
# opencv_frame_2.png written!
# opencv_frame_3.png written!
# opencv_frame_4.png written!
# opencv_frame_5.png written!
# opencv_frame_6.png written!
# opencv_frame_7.png written!
# opencv_frame_8.png written!
# opencv_frame_9.png written!
# opencv_frame_10.png written!
# opencv_frame_11.png written!
# opencv_frame_12.png written!
# opencv_frame_13.png written!
# opencv_frame_14.png written!
# opencv_frame_15.png written!
# opencv_frame_16.png written!
# opencv_frame_17.png written!
# opencv_frame_18.png written!
# opencv_frame_19.png written!
# opencv_frame_20.png written!
# opencv_frame_21.png written!
# opencv_frame_22.png written!
# opencv_frame_23.png written!
# opencv_frame_24.png written!
# opencv_frame_25.png written!
# opencv_frame_26.png written!
# opencv_frame_27.png written!
# opencv_frame_28.png written!
# opencv_frame_29.png written!
# opencv_frame_30.png written!
# opencv_frame_31.png written!
# opencv_frame_32.png written!
# opencv_frame_33.png written!
# opencv_frame_34.png written!
# opencv_frame_35.png written!
# opencv_frame_36.png written!
# opencv_frame_37.png written!
# opencv_frame_38.png written!
# opencv_frame_39.png written!
# opencv_frame_40.png written!
# opencv_frame_41.png written!
# opencv_frame_42.png written!
# opencv_frame_43.png written!
# opencv_frame_44.png written!
# opencv_frame_45.png written!
# opencv_frame_46.png written!
# opencv_frame_47.png written!
# opencv_frame_48.png written!
# opencv_frame_49.png written!
# opencv_frame_50.png written!
# opencv_frame_51.png written!
# opencv_frame_52.png written!
# opencv_frame_53.png written!
# opencv_frame_54.png written!
# opencv_frame_55.png written!
# opencv_frame_56.png written!
# opencv_frame_57.png written!
# opencv_frame_58.png written!
# opencv_frame_59.png written!
# opencv_frame_60.png written!
# opencv_frame_61.png written!
# opencv_frame_62.png written!
# opencv_frame_63.png written!
# opencv_frame_64.png written!
# opencv_frame_65.png written!
# opencv_frame_66.png written!
# opencv_frame_67.png written!
# opencv_frame_68.png written!
# opencv_frame_69.png written!
# opencv_frame_70.png written!
# opencv_frame_71.png written!
# opencv_frame_72.png written!
# opencv_frame_73.png written!
# opencv_frame_74.png written!
# opencv_frame_75.png written!
# opencv_frame_76.png written!
# opencv_frame_77.png written!
# opencv_frame_78.png written!
# opencv_frame_79.png written!
# opencv_frame_80.png written!
# opencv_frame_81.png written!
# opencv_frame_82.png written!
# opencv_frame_83.png written!
# opencv_frame_84.png written!
# opencv_frame_85.png written!
# opencv_frame_86.png written!
# opencv_frame_87.png written!
# opencv_frame_88.png written!
# opencv_frame_89.png written!
# opencv_frame_90.png written!
# opencv_frame_91.png written!
# opencv_frame_92.png written!
# opencv_frame_93.png written!
# opencv_frame_94.png written!
# opencv_frame_95.png written!
# opencv_frame_96.png written!
# opencv_frame_97.png written!
# opencv_frame_98.png written!
# opencv_frame_99.png written!
# opencv_frame_100.png written!
# opencv_frame_101.png written!
# opencv_frame_102.png written!
# opencv_frame_103.png written!
# opencv_frame_104.png written!
# opencv_frame_105.png written!
# opencv_frame_106.png written!
# opencv_frame_107.png written!
# opencv_frame_108.png written!
# opencv_frame_109.png written!
# opencv_frame_110.png written!
# opencv_frame_111.png written!
# opencv_frame_112.png written!
# opencv_frame_113.png written!
# opencv_frame_114.png written!
# opencv_frame_115.png written!
# opencv_frame_116.png written!
# opencv_frame_117.png written!
# opencv_frame_118.png written!
# opencv_frame_119.png written!
# opencv_frame_120.png written!
# opencv_frame_121.png written!
# opencv_frame_122.png written!
# opencv_frame_123.png written!
# opencv_frame_124.png written!
# opencv_frame_125.png written!
# opencv_frame_126.png written!
# opencv_frame_127.png written!
# opencv_frame_128.png written!
# opencv_frame_129.png written!
# opencv_frame_130.png written!
# opencv_frame_131.png written!
# opencv_frame_132.png written!
# opencv_frame_133.png written!
# opencv_frame_134.png written!
# opencv_frame_135.png written!
# opencv_frame_136.png written!
# opencv_frame_137.png written!
# opencv_frame_138.png written!
# opencv_frame_139.png written!
# opencv_frame_140.png written!
# opencv_frame_141.png written!
# opencv_frame_142.png written!
# opencv_frame_143.png written!
# opencv_frame_144.png written!
# opencv_frame_145.png written!
# opencv_frame_146.png written!
# opencv_frame_147.png written!
# opencv_frame_148.png written!
# opencv_frame_149.png written!
# opencv_frame_150.png written!
# opencv_frame_151.png written!
# opencv_frame_152.png written!
# opencv_frame_153.png written!
# opencv_frame_154.png written!
# opencv_frame_155.png written!
# opencv_frame_156.png written!
# opencv_frame_157.png written!
# opencv_frame_158.png written!
# opencv_frame_159.png written!
# opencv_frame_160.png written!
# opencv_frame_161.png written!
# opencv_frame_162.png written!
# opencv_frame_163.png written!
# opencv_frame_164.png written!
# opencv_frame_165.png written!
# opencv_frame_166.png written!
# opencv_frame_167.png written!
# opencv_frame_168.png written!
# opencv_frame_169.png written!
# opencv_frame_170.png written!
# opencv_frame_171.png written!
# opencv_frame_172.png written!
# opencv_frame_173.png written!
# opencv_frame_174.png written!
# opencv_frame_175.png written!
# opencv_frame_176.png written!
# opencv_frame_177.png written!
# opencv_frame_178.png written!
# opencv_frame_179.png written!
# opencv_frame_180.png written!
# opencv_frame_181.png written!
# opencv_frame_182.png written!
# opencv_frame_183.png written!
# opencv_frame_184.png written!
# opencv_frame_185.png written!
# opencv_frame_186.png written!
# opencv_frame_187.png written!
# opencv_frame_188.png written!
# opencv_frame_189.png written!
# opencv_frame_190.png written!
# opencv_frame_191.png written!
# opencv_frame_192.png written!
# opencv_frame_193.png written!
# opencv_frame_194.png written!
# opencv_frame_195.png written!
# opencv_frame_196.png written!
# opencv_frame_197.png written!
# opencv_frame_198.png written!
# opencv_frame_199.png written!
# opencv_frame_200.png written!
# opencv_frame_201.png written!
# opencv_frame_202.png written!
# opencv_frame_203.png written!
# opencv_frame_204.png written!
# opencv_frame_205.png written!
# opencv_frame_206.png written!
# opencv_frame_207.png written!
# opencv_frame_208.png written!
# opencv_frame_209.png written!
# opencv_frame_210.png written!
# opencv_frame_211.png written!
# opencv_frame_212.png written!
# opencv_frame_213.png written!
# opencv_frame_214.png written!
# opencv_frame_215.png written!
# opencv_frame_216.png written!
# opencv_frame_217.png written!
# opencv_frame_218.png written!
# opencv_frame_219.png written!
# opencv_frame_220.png written!
# opencv_frame_221.png written!
# opencv_frame_222.png written!
# opencv_frame_223.png written!
# opencv_frame_224.png written!
# opencv_frame_225.png written!
# opencv_frame_226.png written!
# opencv_frame_227.png written!
# opencv_frame_228.png written!
# opencv_frame_229.png written!
# opencv_frame_230.png written!
# opencv_frame_231.png written!
# opencv_frame_232.png written!
# opencv_frame_233.png written!
# opencv_frame_234.png written!
# opencv_frame_235.png written!
# opencv_frame_236.png written!
# opencv_frame_237.png written!
# opencv_frame_238.png written!
# opencv_frame_239.png written!
# opencv_frame_240.png written!
# opencv_frame_241.png written!
# opencv_frame_242.png written!
# opencv_frame_243.png written!
# opencv_frame_244.png written!
# opencv_frame_245.png written!
# opencv_frame_246.png written!
# opencv_frame_247.png written!
# opencv_frame_248.png written!
# opencv_frame_249.png written!
# opencv_frame_250.png written!
# opencv_frame_251.png written!
# opencv_frame_252.png written!
# opencv_frame_253.png written!
# opencv_frame_254.png written!
# opencv_frame_255.png written!
# opencv_frame_256.png written!
# opencv_frame_257.png written!
# opencv_frame_258.png written!
# opencv_frame_259.png written!
# opencv_frame_260.png written!
# opencv_frame_261.png written!
# opencv_frame_262.png written!
# opencv_frame_263.png written!
# opencv_frame_264.png written!
# opencv_frame_265.png written!
# opencv_frame_266.png written!
# opencv_frame_267.png written!
# opencv_frame_268.png written!
# opencv_frame_269.png written!
# opencv_frame_270.png written!
# opencv_frame_271.png written!
# opencv_frame_272.png written!
# opencv_frame_273.png written!
# opencv_frame_274.png written!
# opencv_frame_275.png written!
# opencv_frame_276.png written!
# opencv_frame_277.png written!
# opencv_frame_278.png written!
# opencv_frame_279.png written!
# opencv_frame_280.png written!
# opencv_frame_281.png written!
# opencv_frame_282.png written!
# opencv_frame_283.png written!
# opencv_frame_284.png written!
# opencv_frame_285.png written!
# opencv_frame_286.png written!
# opencv_frame_287.png written!
# opencv_frame_288.png written!
# opencv_frame_289.png written!
# opencv_frame_290.png written!
# opencv_frame_291.png written!
# opencv_frame_292.png written!
# opencv_frame_293.png written!
# opencv_frame_294.png written!
# opencv_frame_295.png written!
# opencv_frame_296.png written!
# opencv_frame_297.png written!
# opencv_frame_298.png written!
# opencv_frame_299.png written!
# opencv_frame_300.png written!
# opencv_frame_301.png written!
# opencv_frame_302.png written!
# opencv_frame_303.png written!
# opencv_frame_304.png written!
# opencv_frame_305.png written!
# opencv_frame_306.png written!
# opencv_frame_307.png written!
# opencv_frame_308.png written!
# opencv_frame_309.png written!
# opencv_frame_310.png written!
# opencv_frame_311.png written!
# opencv_frame_312.png written!
# opencv_frame_313.png written!
# opencv_frame_314.png written!
# opencv_frame_315.png written!
# opencv_frame_316.png written!
# opencv_frame_317.png written!
# opencv_frame_318.png written!
# opencv_frame_319.png written!
# opencv_frame_320.png written!
# opencv_frame_321.png written!
# opencv_frame_322.png written!
# opencv_frame_323.png written!
# opencv_frame_324.png written!
# opencv_frame_325.png written!
# opencv_frame_326.png written!
# opencv_frame_327.png written!
# opencv_frame_328.png written!
# opencv_frame_329.png written!
# opencv_frame_330.png written!
# opencv_frame_331.png written!
# opencv_frame_332.png written!
# opencv_frame_333.png written!
# opencv_frame_334.png written!
# opencv_frame_335.png written!
# opencv_frame_336.png written!
# opencv_frame_337.png written!
# opencv_frame_338.png written!
# opencv_frame_339.png written!
# opencv_frame_340.png written!
# opencv_frame_341.png written!
# opencv_frame_342.png written!
# opencv_frame_343.png written!
# opencv_frame_344.png written!
# opencv_frame_345.png written!
# opencv_frame_346.png written!
# opencv_frame_347.png written!
# opencv_frame_348.png written!
# opencv_frame_349.png written!
# opencv_frame_350.png written!
# opencv_frame_351.png written!
# opencv_frame_352.png written!
# opencv_frame_353.png written!
# opencv_frame_354.png written!
# opencv_frame_355.png written!
# opencv_frame_356.png written!
# opencv_frame_357.png written!
# opencv_frame_358.png written!
# opencv_frame_359.png written!
# opencv_frame_360.png written!
# opencv_frame_361.png written!
# opencv_frame_362.png written!
# opencv_frame_363.png written!
# opencv_frame_364.png written!
# opencv_frame_365.png written!
# opencv_frame_366.png written!
# opencv_frame_367.png written!
# opencv_frame_368.png written!
# opencv_frame_369.png written!
# opencv_frame_370.png written!
# opencv_frame_371.png written!
# opencv_frame_372.png written!
# opencv_frame_373.png written!
# opencv_frame_374.png written!
# opencv_frame_375.png written!
# opencv_frame_376.png written!
# opencv_frame_377.png written!
# opencv_frame_378.png written!
# opencv_frame_379.png written!
# opencv_frame_380.png written!
# opencv_frame_381.png written!
# opencv_frame_382.png written!
# opencv_frame_383.png written!
# opencv_frame_384.png written!
# opencv_frame_385.png written!
# opencv_frame_386.png written!
# opencv_frame_387.png written!
# opencv_frame_388.png written!
# opencv_frame_389.png written!
# opencv_frame_390.png written!
# opencv_frame_391.png written!
# opencv_frame_392.png written!
# opencv_frame_393.png written!
# opencv_frame_394.png written!
# opencv_frame_395.png written!
# opencv_frame_396.png written!
# opencv_frame_397.png written!
# opencv_frame_398.png written!
# opencv_frame_399.png written!
# opencv_frame_400.png written!
# opencv_frame_401.png written!
# opencv_frame_402.png written!
# opencv_frame_403.png written!
# opencv_frame_404.png written!
# opencv_frame_405.png written!
# opencv_frame_406.png written!
# opencv_frame_407.png written!
# opencv_frame_408.png written!
# opencv_frame_409.png written!
# opencv_frame_410.png written!
# opencv_frame_411.png written!
# opencv_frame_412.png written!
# opencv_frame_413.png written!
# opencv_frame_414.png written!
# opencv_frame_415.png written!
# opencv_frame_416.png written!
# opencv_frame_417.png written!
# opencv_frame_418.png written!
# opencv_frame_419.png written!
# opencv_frame_420.png written!
# opencv_frame_421.png written!
# opencv_frame_422.png written!
# opencv_frame_423.png written!
# opencv_frame_424.png written!
# opencv_frame_425.png written!
# opencv_frame_426.png written!
# opencv_frame_427.png written!
# opencv_frame_428.png written!
# opencv_frame_429.png written!
# opencv_frame_430.png written!
# opencv_frame_431.png written!
# opencv_frame_432.png written!
# opencv_frame_433.png written!
# opencv_frame_434.png written!
# opencv_frame_435.png written!
# opencv_frame_436.png written!
# opencv_frame_437.png written!
# opencv_frame_438.png written!
# opencv_frame_439.png written!
# opencv_frame_440.png written!
# opencv_frame_441.png written!
# opencv_frame_442.png written!
# opencv_frame_443.png written!
# opencv_frame_444.png written!
# opencv_frame_445.png written!
# opencv_frame_446.png written!
# opencv_frame_447.png written!
# opencv_frame_448.png written!
# opencv_frame_449.png written!
# opencv_frame_450.png written!
# opencv_frame_451.png written!
# opencv_frame_452.png written!
# opencv_frame_453.png written!
# opencv_frame_454.png written!
# opencv_frame_455.png written!
# opencv_frame_456.png written!
# opencv_frame_457.png written!
# opencv_frame_458.png written!
# opencv_frame_459.png written!
# opencv_frame_460.png written!
# opencv_frame_461.png written!
# opencv_frame_462.png written!
# opencv_frame_463.png written!
# opencv_frame_464.png written!
# opencv_frame_465.png written!
# opencv_frame_466.png written!
# opencv_frame_467.png written!
# opencv_frame_468.png written!
# opencv_frame_469.png written!
# opencv_frame_470.png written!
# opencv_frame_471.png written!
# opencv_frame_472.png written!
# opencv_frame_473.png written!
# opencv_frame_474.png written!
# opencv_frame_475.png written!
# opencv_frame_476.png written!
# opencv_frame_477.png written!
# opencv_frame_478.png written!
# opencv_frame_479.png written!
# opencv_frame_480.png written!
# opencv_frame_481.png written!
# opencv_frame_482.png written!
# opencv_frame_483.png written!
# opencv_frame_484.png written!
# opencv_frame_485.png written!
# opencv_frame_486.png written!
# opencv_frame_487.png written!
# opencv_frame_488.png written!
# opencv_frame_489.png written!
# opencv_frame_490.png written!
# opencv_frame_491.png written!
# opencv_frame_492.png written!
# opencv_frame_493.png written!
# opencv_frame_494.png written!
# opencv_frame_495.png written!
# opencv_frame_496.png written!
# opencv_frame_497.png written!
# opencv_frame_498.png written!
# opencv_frame_499.png written!
# opencv_frame_500.png written!
# opencv_frame_501.png written!
# opencv_frame_502.png written!
# opencv_frame_503.png written!
# opencv_frame_504.png written!
# opencv_frame_505.png written!
# opencv_frame_506.png written!
# opencv_frame_507.png written!
# opencv_frame_508.png written!
# opencv_frame_509.png written!
# opencv_frame_510.png written!
# opencv_frame_511.png written!
# Escape hit, closing...

# %%
get_images("lizard")
# Out:
# opencv_frame_0.png written!
# opencv_frame_1.png written!
# opencv_frame_2.png written!
# opencv_frame_3.png written!
# opencv_frame_4.png written!
# opencv_frame_5.png written!
# opencv_frame_6.png written!
# opencv_frame_7.png written!
# opencv_frame_8.png written!
# opencv_frame_9.png written!
# opencv_frame_10.png written!
# opencv_frame_11.png written!
# opencv_frame_12.png written!
# opencv_frame_13.png written!
# opencv_frame_14.png written!
# opencv_frame_15.png written!
# opencv_frame_16.png written!
# opencv_frame_17.png written!
# opencv_frame_18.png written!
# opencv_frame_19.png written!
# opencv_frame_20.png written!
# opencv_frame_21.png written!
# opencv_frame_22.png written!
# opencv_frame_23.png written!
# opencv_frame_24.png written!
# opencv_frame_25.png written!
# opencv_frame_26.png written!
# opencv_frame_27.png written!
# opencv_frame_28.png written!
# opencv_frame_29.png written!
# opencv_frame_30.png written!
# opencv_frame_31.png written!
# opencv_frame_32.png written!
# opencv_frame_33.png written!
# opencv_frame_34.png written!
# opencv_frame_35.png written!
# opencv_frame_36.png written!
# opencv_frame_37.png written!
# opencv_frame_38.png written!
# opencv_frame_39.png written!
# opencv_frame_40.png written!
# opencv_frame_41.png written!
# opencv_frame_42.png written!
# opencv_frame_43.png written!
# opencv_frame_44.png written!
# opencv_frame_45.png written!
# opencv_frame_46.png written!
# opencv_frame_47.png written!
# opencv_frame_48.png written!
# opencv_frame_49.png written!
# opencv_frame_50.png written!
# opencv_frame_51.png written!
# opencv_frame_52.png written!
# opencv_frame_53.png written!
# opencv_frame_54.png written!
# opencv_frame_55.png written!
# opencv_frame_56.png written!
# opencv_frame_57.png written!
# opencv_frame_58.png written!
# opencv_frame_59.png written!
# opencv_frame_60.png written!
# opencv_frame_61.png written!
# opencv_frame_62.png written!
# opencv_frame_63.png written!
# opencv_frame_64.png written!
# opencv_frame_65.png written!
# opencv_frame_66.png written!
# opencv_frame_67.png written!
# opencv_frame_68.png written!
# opencv_frame_69.png written!
# opencv_frame_70.png written!
# opencv_frame_71.png written!
# opencv_frame_72.png written!
# opencv_frame_73.png written!
# opencv_frame_74.png written!
# opencv_frame_75.png written!
# opencv_frame_76.png written!
# opencv_frame_77.png written!
# opencv_frame_78.png written!
# opencv_frame_79.png written!
# opencv_frame_80.png written!
# opencv_frame_81.png written!
# opencv_frame_82.png written!
# opencv_frame_83.png written!
# opencv_frame_84.png written!
# opencv_frame_85.png written!
# opencv_frame_86.png written!
# opencv_frame_87.png written!
# opencv_frame_88.png written!
# opencv_frame_89.png written!
# opencv_frame_90.png written!
# opencv_frame_91.png written!
# opencv_frame_92.png written!
# opencv_frame_93.png written!
# opencv_frame_94.png written!
# opencv_frame_95.png written!
# opencv_frame_96.png written!
# opencv_frame_97.png written!
# opencv_frame_98.png written!
# opencv_frame_99.png written!
# opencv_frame_100.png written!
# opencv_frame_101.png written!
# opencv_frame_102.png written!
# opencv_frame_103.png written!
# opencv_frame_104.png written!
# opencv_frame_105.png written!
# opencv_frame_106.png written!
# opencv_frame_107.png written!
# opencv_frame_108.png written!
# opencv_frame_109.png written!
# opencv_frame_110.png written!
# opencv_frame_111.png written!
# opencv_frame_112.png written!
# opencv_frame_113.png written!
# opencv_frame_114.png written!
# opencv_frame_115.png written!
# opencv_frame_116.png written!
# opencv_frame_117.png written!
# opencv_frame_118.png written!
# opencv_frame_119.png written!
# opencv_frame_120.png written!
# opencv_frame_121.png written!
# opencv_frame_122.png written!
# opencv_frame_123.png written!
# opencv_frame_124.png written!
# opencv_frame_125.png written!
# opencv_frame_126.png written!
# opencv_frame_127.png written!
# opencv_frame_128.png written!
# opencv_frame_129.png written!
# opencv_frame_130.png written!
# opencv_frame_131.png written!
# opencv_frame_132.png written!
# opencv_frame_133.png written!
# opencv_frame_134.png written!
# opencv_frame_135.png written!
# opencv_frame_136.png written!
# opencv_frame_137.png written!
# opencv_frame_138.png written!
# opencv_frame_139.png written!
# opencv_frame_140.png written!
# opencv_frame_141.png written!
# opencv_frame_142.png written!
# opencv_frame_143.png written!
# opencv_frame_144.png written!
# opencv_frame_145.png written!
# opencv_frame_146.png written!
# opencv_frame_147.png written!
# opencv_frame_148.png written!
# opencv_frame_149.png written!
# opencv_frame_150.png written!
# opencv_frame_151.png written!
# opencv_frame_152.png written!
# opencv_frame_153.png written!
# opencv_frame_154.png written!
# opencv_frame_155.png written!
# opencv_frame_156.png written!
# opencv_frame_157.png written!
# opencv_frame_158.png written!
# opencv_frame_159.png written!
# opencv_frame_160.png written!
# opencv_frame_161.png written!
# opencv_frame_162.png written!
# opencv_frame_163.png written!
# opencv_frame_164.png written!
# opencv_frame_165.png written!
# opencv_frame_166.png written!
# opencv_frame_167.png written!
# opencv_frame_168.png written!
# opencv_frame_169.png written!
# opencv_frame_170.png written!
# opencv_frame_171.png written!
# opencv_frame_172.png written!
# opencv_frame_173.png written!
# opencv_frame_174.png written!
# opencv_frame_175.png written!
# opencv_frame_176.png written!
# opencv_frame_177.png written!
# opencv_frame_178.png written!
# opencv_frame_179.png written!
# opencv_frame_180.png written!
# opencv_frame_181.png written!
# opencv_frame_182.png written!
# opencv_frame_183.png written!
# opencv_frame_184.png written!
# opencv_frame_185.png written!
# opencv_frame_186.png written!
# opencv_frame_187.png written!
# opencv_frame_188.png written!
# opencv_frame_189.png written!
# opencv_frame_190.png written!
# opencv_frame_191.png written!
# opencv_frame_192.png written!
# opencv_frame_193.png written!
# opencv_frame_194.png written!
# opencv_frame_195.png written!
# opencv_frame_196.png written!
# opencv_frame_197.png written!
# opencv_frame_198.png written!
# opencv_frame_199.png written!
# opencv_frame_200.png written!
# opencv_frame_201.png written!
# opencv_frame_202.png written!
# opencv_frame_203.png written!
# opencv_frame_204.png written!
# opencv_frame_205.png written!
# opencv_frame_206.png written!
# opencv_frame_207.png written!
# opencv_frame_208.png written!
# opencv_frame_209.png written!
# opencv_frame_210.png written!
# opencv_frame_211.png written!
# opencv_frame_212.png written!
# opencv_frame_213.png written!
# opencv_frame_214.png written!
# opencv_frame_215.png written!
# opencv_frame_216.png written!
# opencv_frame_217.png written!
# opencv_frame_218.png written!
# opencv_frame_219.png written!
# opencv_frame_220.png written!
# opencv_frame_221.png written!
# opencv_frame_222.png written!
# opencv_frame_223.png written!
# opencv_frame_224.png written!
# opencv_frame_225.png written!
# opencv_frame_226.png written!
# opencv_frame_227.png written!
# opencv_frame_228.png written!
# opencv_frame_229.png written!
# opencv_frame_230.png written!
# opencv_frame_231.png written!
# opencv_frame_232.png written!
# opencv_frame_233.png written!
# opencv_frame_234.png written!
# opencv_frame_235.png written!
# opencv_frame_236.png written!
# opencv_frame_237.png written!
# opencv_frame_238.png written!
# opencv_frame_239.png written!
# opencv_frame_240.png written!
# opencv_frame_241.png written!
# opencv_frame_242.png written!
# opencv_frame_243.png written!
# opencv_frame_244.png written!
# opencv_frame_245.png written!
# opencv_frame_246.png written!
# opencv_frame_247.png written!
# opencv_frame_248.png written!
# opencv_frame_249.png written!
# opencv_frame_250.png written!
# opencv_frame_251.png written!
# opencv_frame_252.png written!
# opencv_frame_253.png written!
# opencv_frame_254.png written!
# opencv_frame_255.png written!
# opencv_frame_256.png written!
# opencv_frame_257.png written!
# opencv_frame_258.png written!
# opencv_frame_259.png written!
# opencv_frame_260.png written!
# opencv_frame_261.png written!
# opencv_frame_262.png written!
# opencv_frame_263.png written!
# opencv_frame_264.png written!
# opencv_frame_265.png written!
# opencv_frame_266.png written!
# opencv_frame_267.png written!
# opencv_frame_268.png written!
# opencv_frame_269.png written!
# opencv_frame_270.png written!
# opencv_frame_271.png written!
# opencv_frame_272.png written!
# opencv_frame_273.png written!
# opencv_frame_274.png written!
# opencv_frame_275.png written!
# opencv_frame_276.png written!
# opencv_frame_277.png written!
# opencv_frame_278.png written!
# opencv_frame_279.png written!
# opencv_frame_280.png written!
# opencv_frame_281.png written!
# opencv_frame_282.png written!
# opencv_frame_283.png written!
# opencv_frame_284.png written!
# opencv_frame_285.png written!
# opencv_frame_286.png written!
# opencv_frame_287.png written!
# opencv_frame_288.png written!
# opencv_frame_289.png written!
# opencv_frame_290.png written!
# opencv_frame_291.png written!
# opencv_frame_292.png written!
# opencv_frame_293.png written!
# opencv_frame_294.png written!
# opencv_frame_295.png written!
# opencv_frame_296.png written!
# opencv_frame_297.png written!
# opencv_frame_298.png written!
# opencv_frame_299.png written!
# opencv_frame_300.png written!
# opencv_frame_301.png written!
# opencv_frame_302.png written!
# opencv_frame_303.png written!
# opencv_frame_304.png written!
# opencv_frame_305.png written!
# opencv_frame_306.png written!
# opencv_frame_307.png written!
# opencv_frame_308.png written!
# opencv_frame_309.png written!
# opencv_frame_310.png written!
# opencv_frame_311.png written!
# opencv_frame_312.png written!
# opencv_frame_313.png written!
# opencv_frame_314.png written!
# opencv_frame_315.png written!
# opencv_frame_316.png written!
# opencv_frame_317.png written!
# opencv_frame_318.png written!
# opencv_frame_319.png written!
# opencv_frame_320.png written!
# opencv_frame_321.png written!
# opencv_frame_322.png written!
# opencv_frame_323.png written!
# opencv_frame_324.png written!
# opencv_frame_325.png written!
# opencv_frame_326.png written!
# opencv_frame_327.png written!
# opencv_frame_328.png written!
# opencv_frame_329.png written!
# opencv_frame_330.png written!
# opencv_frame_331.png written!
# opencv_frame_332.png written!
# opencv_frame_333.png written!
# opencv_frame_334.png written!
# opencv_frame_335.png written!
# opencv_frame_336.png written!
# opencv_frame_337.png written!
# opencv_frame_338.png written!
# opencv_frame_339.png written!
# opencv_frame_340.png written!
# opencv_frame_341.png written!
# opencv_frame_342.png written!
# opencv_frame_343.png written!
# opencv_frame_344.png written!
# opencv_frame_345.png written!
# opencv_frame_346.png written!
# opencv_frame_347.png written!
# opencv_frame_348.png written!
# opencv_frame_349.png written!
# opencv_frame_350.png written!
# opencv_frame_351.png written!
# opencv_frame_352.png written!
# opencv_frame_353.png written!
# opencv_frame_354.png written!
# opencv_frame_355.png written!
# opencv_frame_356.png written!
# opencv_frame_357.png written!
# opencv_frame_358.png written!
# opencv_frame_359.png written!
# opencv_frame_360.png written!
# opencv_frame_361.png written!
# opencv_frame_362.png written!
# opencv_frame_363.png written!
# opencv_frame_364.png written!
# opencv_frame_365.png written!
# opencv_frame_366.png written!
# opencv_frame_367.png written!
# opencv_frame_368.png written!
# opencv_frame_369.png written!
# opencv_frame_370.png written!
# opencv_frame_371.png written!
# opencv_frame_372.png written!
# opencv_frame_373.png written!
# opencv_frame_374.png written!
# opencv_frame_375.png written!
# opencv_frame_376.png written!
# opencv_frame_377.png written!
# opencv_frame_378.png written!
# opencv_frame_379.png written!
# opencv_frame_380.png written!
# opencv_frame_381.png written!
# opencv_frame_382.png written!
# opencv_frame_383.png written!
# opencv_frame_384.png written!
# opencv_frame_385.png written!
# opencv_frame_386.png written!
# opencv_frame_387.png written!
# opencv_frame_388.png written!
# opencv_frame_389.png written!
# opencv_frame_390.png written!
# opencv_frame_391.png written!
# opencv_frame_392.png written!
# opencv_frame_393.png written!
# opencv_frame_394.png written!
# opencv_frame_395.png written!
# opencv_frame_396.png written!
# opencv_frame_397.png written!
# opencv_frame_398.png written!
# opencv_frame_399.png written!
# opencv_frame_400.png written!
# opencv_frame_401.png written!
# opencv_frame_402.png written!
# opencv_frame_403.png written!
# opencv_frame_404.png written!
# opencv_frame_405.png written!
# opencv_frame_406.png written!
# opencv_frame_407.png written!
# opencv_frame_408.png written!
# opencv_frame_409.png written!
# opencv_frame_410.png written!
# opencv_frame_411.png written!
# opencv_frame_412.png written!
# opencv_frame_413.png written!
# opencv_frame_414.png written!
# opencv_frame_415.png written!
# opencv_frame_416.png written!
# opencv_frame_417.png written!
# opencv_frame_418.png written!
# opencv_frame_419.png written!
# opencv_frame_420.png written!
# opencv_frame_421.png written!
# opencv_frame_422.png written!
# opencv_frame_423.png written!
# opencv_frame_424.png written!
# opencv_frame_425.png written!
# opencv_frame_426.png written!
# opencv_frame_427.png written!
# opencv_frame_428.png written!
# opencv_frame_429.png written!
# opencv_frame_430.png written!
# opencv_frame_431.png written!
# opencv_frame_432.png written!
# opencv_frame_433.png written!
# opencv_frame_434.png written!
# opencv_frame_435.png written!
# opencv_frame_436.png written!
# opencv_frame_437.png written!
# opencv_frame_438.png written!
# opencv_frame_439.png written!
# opencv_frame_440.png written!
# opencv_frame_441.png written!
# opencv_frame_442.png written!
# opencv_frame_443.png written!
# opencv_frame_444.png written!
# opencv_frame_445.png written!
# opencv_frame_446.png written!
# opencv_frame_447.png written!
# opencv_frame_448.png written!
# opencv_frame_449.png written!
# opencv_frame_450.png written!
# opencv_frame_451.png written!
# opencv_frame_452.png written!
# opencv_frame_453.png written!
# opencv_frame_454.png written!
# opencv_frame_455.png written!
# opencv_frame_456.png written!
# opencv_frame_457.png written!
# opencv_frame_458.png written!
# opencv_frame_459.png written!
# opencv_frame_460.png written!
# opencv_frame_461.png written!
# opencv_frame_462.png written!
# opencv_frame_463.png written!
# opencv_frame_464.png written!
# opencv_frame_465.png written!
# opencv_frame_466.png written!
# opencv_frame_467.png written!
# opencv_frame_468.png written!
# opencv_frame_469.png written!
# opencv_frame_470.png written!
# opencv_frame_471.png written!
# opencv_frame_472.png written!
# opencv_frame_473.png written!
# opencv_frame_474.png written!
# opencv_frame_475.png written!
# opencv_frame_476.png written!
# opencv_frame_477.png written!
# opencv_frame_478.png written!
# opencv_frame_479.png written!
# opencv_frame_480.png written!
# opencv_frame_481.png written!
# opencv_frame_482.png written!
# opencv_frame_483.png written!
# opencv_frame_484.png written!
# opencv_frame_485.png written!
# opencv_frame_486.png written!
# opencv_frame_487.png written!
# opencv_frame_488.png written!
# opencv_frame_489.png written!
# opencv_frame_490.png written!
# opencv_frame_491.png written!
# opencv_frame_492.png written!
# opencv_frame_493.png written!
# opencv_frame_494.png written!
# opencv_frame_495.png written!
# opencv_frame_496.png written!
# opencv_frame_497.png written!
# opencv_frame_498.png written!
# opencv_frame_499.png written!
# opencv_frame_500.png written!
# Escape hit, closing...
